# %% [markdown]
# # Notes
#
# Check whether stemming & lemmatization make difference
#
# Do we need bigram/trigram frequencies (within titles)?
#
# Do we need dataframe including cleaned data & genres? (which cleaned data?) -> create dictionary of lists maybe
# https://www.geeksforgeeks.org/python-ways-to-create-a-dictionary-of-lists/
#
# How do we incorporate POS-tagging & NER in classifier?

# %% [markdown]
# # Importing & Cleaning data
#
# This section imports the data into a pandas dataframe and goes through the following preprocessing steps:
#
# -Case collapsing
# -Remove punctuation
# -Tokenization
# -N-Grams: bigrams and trigrams
# -Stemming -> check whether this makes a difference
# -Lemmatization -> check whether this makes a difference
# -Part-of-speech (POS) tagging
# -Named entity recognition (NER)

# %% [markdown]
# ## Import Data
#
# Imports data as pandas dataframe
#
# Create list of title and genre columns from original data
#
# Create list including all 32 genres

# %%
import pandas as pd
df = pd.read_csv(r'/Users/feliciaheilgendorff/Documents/AU/NLP/NLP-Project/amazon/book32listing.csv', encoding='latin1', header=None)
df1 = df[[3,6]] # only columns with titles and genres
df1.columns = ['title', 'genre']
print(df1[:5])
# Out:
#                                                title      genre
# 0                    Mom's Family Wall Calendar 2016  Calendars
# 1                    Doug the Pug 2016 Wall Calendar  Calendars
# 2  Moleskine 2016 Weekly Notebook, 12M, Large, Bl...  Calendars
# 3            365 Cats Color Page-A-Day Calendar 2016  Calendars
# 4               Sierra Club Engagement Calendar 2016  Calendars

# %%
titles = df1['title'] # list of all titles
titles1 = titles.values.tolist() # change to list of strings
print(titles1[0:5]) # test whether it worked
# Out:
# ["Mom's Family Wall Calendar 2016", 'Doug the Pug 2016 Wall Calendar', 'Moleskine 2016 Weekly Notebook, 12M, Large, Black, Soft Cover (5 x 8.25)', '365 Cats Color Page-A-Day Calendar 2016', 'Sierra Club Engagement Calendar 2016']

# %%
genres = df1['genre']
genres = genres.values.tolist()
genres = pd.DataFrame(genres)

# %%
df1.genre.unique() # list of all possible genres
# Out:
# array(['Calendars', 'Comics & Graphic Novels', 'Test Preparation',
#        'Mystery, Thriller & Suspense', 'Science Fiction & Fantasy',
#        'Romance', 'Humor & Entertainment', 'Literature & Fiction',
#        'Gay & Lesbian', 'Engineering & Transportation',
#        'Cookbooks, Food & Wine', 'Crafts, Hobbies & Home',
#        'Arts & Photography', 'Education & Teaching',
#        'Parenting & Relationships', 'Self-Help', 'Computers & Technology',
#        'Medical Books', 'Science & Math', 'Health, Fitness & Dieting',
#        'Business & Money', 'Law', 'Biographies & Memoirs', 'History',
#        'Politics & Social Sciences', 'Reference',
#        'Christian Books & Bibles', 'Religion & Spirituality',
#        'Sports & Outdoors', 'Teen & Young Adult', "Children's Books",
#        'Travel'], dtype=object)

# %% [markdown]
# ## Case Collapsing
# Change all uppercase to lowercase letters

# %%
case_collap = map(lambda x:x.lower(), titles1)
case_collap_list = list(case_collap)
print(case_collap_list[0:5])
# Out:
# ["mom's family wall calendar 2016", 'doug the pug 2016 wall calendar', 'moleskine 2016 weekly notebook, 12m, large, black, soft cover (5 x 8.25)', '365 cats color page-a-day calendar 2016', 'sierra club engagement calendar 2016']

# %% [markdown]
# ## Remove Punctuation
# Remove punctuation by creating translation table
#
# Punctuation to be removed is given in string: string.punctuation

# %%
import string
trans = str.maketrans('', '', string.punctuation)
rem_punct = [s.translate(trans) for s in case_collap_list]
print(rem_punct[0:5])
# Out:
# ['moms family wall calendar 2016', 'doug the pug 2016 wall calendar', 'moleskine 2016 weekly notebook 12m large black soft cover 5 x 825', '365 cats color pageaday calendar 2016', 'sierra club engagement calendar 2016']

# %% [markdown]
# ## Tokenization
# Split all titles into words (output: list of lists of strings)

# %%
import nltk
from nltk.tokenize import word_tokenize
tokenized_titles = [word_tokenize(i) for i in rem_punct]
print(tokenized_titles[:5])
# Out:
# [['moms', 'family', 'wall', 'calendar', '2016'], ['doug', 'the', 'pug', '2016', 'wall', 'calendar'], ['moleskine', '2016', 'weekly', 'notebook', '12m', 'large', 'black', 'soft', 'cover', '5', 'x', '825'], ['365', 'cats', 'color', 'pageaday', 'calendar', '2016'], ['sierra', 'club', 'engagement', 'calendar', '2016']]

# %% [markdown]
# ## N-Grams: Bigrams and Trigrams
# Create bigrams + trigrams (could be done in one go e.g. n=2 for bigrams, n=3 for trigrams etc.)

# %%
# bigrams
token_bigram = []
for title in tokenized_titles:
    title_bigram = []
    for w in range(len(title) - 1):
        title_bigram.append([title[w], title[w + 1]])
    token_bigram.append(title_bigram)
print(token_bigram[:5]) # test whether working
# Out:
# [[['moms', 'family'], ['family', 'wall'], ['wall', 'calendar'], ['calendar', '2016']], [['doug', 'the'], ['the', 'pug'], ['pug', '2016'], ['2016', 'wall'], ['wall', 'calendar']], [['moleskine', '2016'], ['2016', 'weekly'], ['weekly', 'notebook'], ['notebook', '12m'], ['12m', 'large'], ['large', 'black'], ['black', 'soft'], ['soft', 'cover'], ['cover', '5'], ['5', 'x'], ['x', '825']], [['365', 'cats'], ['cats', 'color'], ['color', 'pageaday'], ['pageaday', 'calendar'], ['calendar', '2016']], [['sierra', 'club'], ['club', 'engagement'], ['engagement', 'calendar'], ['calendar', '2016']]]

# %%
# trigrams
token_trigram = []
for title in tokenized_titles:
    title_trigram = []
    for w in range(len(title) - 2):
        title_trigram.append([title[w], title[w + 1], title[w + 2]])
    token_trigram.append(title_trigram)
print(token_trigram[:5]) # test whether working
# Out:
# [[['moms', 'family', 'wall'], ['family', 'wall', 'calendar'], ['wall', 'calendar', '2016']], [['doug', 'the', 'pug'], ['the', 'pug', '2016'], ['pug', '2016', 'wall'], ['2016', 'wall', 'calendar']], [['moleskine', '2016', 'weekly'], ['2016', 'weekly', 'notebook'], ['weekly', 'notebook', '12m'], ['notebook', '12m', 'large'], ['12m', 'large', 'black'], ['large', 'black', 'soft'], ['black', 'soft', 'cover'], ['soft', 'cover', '5'], ['cover', '5', 'x'], ['5', 'x', '825']], [['365', 'cats', 'color'], ['cats', 'color', 'pageaday'], ['color', 'pageaday', 'calendar'], ['pageaday', 'calendar', '2016']], [['sierra', 'club', 'engagement'], ['club', 'engagement', 'calendar'], ['engagement', 'calendar', '2016']]]

# %% [markdown]
# ## Stemming
# Test this out to see whether it makes a difference in final classifier
#
# PorterStemmer (one algorithm for stemming; less aggressive than LancasterStemming)
#
#
# Create empty list to contain lists of stems in each title
#
# Create empty list for stems of title
#
# Add each stemmed word in title to second list
#
# Append list of stemmed words to first list

# %%
from nltk.stem import PorterStemmer

porter = PorterStemmer()
stems = []   
for title in tokenized_titles:
    stems_title = []
    for word in title:
        stems_title.append(porter.stem(word))
    stems.append(stems_title)
    
print(stems[0:5]) # test whether it works
# Out:
# [['mom', 'famili', 'wall', 'calendar', '2016'], ['doug', 'the', 'pug', '2016', 'wall', 'calendar'], ['moleskin', '2016', 'weekli', 'notebook', '12m', 'larg', 'black', 'soft', 'cover', '5', 'x', '825'], ['365', 'cat', 'color', 'pageaday', 'calendar', '2016'], ['sierra', 'club', 'engag', 'calendar', '2016']]

# %% [markdown]
# ## Lemmatization
#
# Same principle as with stemming
#
# Test this out to see whether it makes a difference in final classifier

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmas = []
for title in tokenized_titles:
    lemmas_title = []
    for word in title:
        lemmas_title.append(lemmatizer.lemmatize(word))
    lemmas.append(lemmas_title)
    
print(lemmas[0:5]) # test whether it works
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/feliciaheilgendorff/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [['mom', 'family', 'wall', 'calendar', '2016'], ['doug', 'the', 'pug', '2016', 'wall', 'calendar'], ['moleskine', '2016', 'weekly', 'notebook', '12m', 'large', 'black', 'soft', 'cover', '5', 'x', '825'], ['365', 'cat', 'color', 'pageaday', 'calendar', '2016'], ['sierra', 'club', 'engagement', 'calendar', '2016'], ['sierra', 'club', 'wilderness', 'calendar', '2016']]

# %% [markdown]
# ## Part-of-Speech (POS) Tagging
# Create list of lists with tokens and their corresponding part-of-speech tag in each title

# %%
nltk.download('averaged_perceptron_tagger')
from nltk.tag import pos_tag

postag = []
for title in tokenized_titles:
    postag.append(nltk.pos_tag(title))
    
print(postag[0:5]) # testing whether postag worked
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/feliciaheilgendorff/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [[('moms', 'NNS'), ('family', 'NN'), ('wall', 'NN'), ('calendar', 'NN'), ('2016', 'CD')], [('doug', 'VB'), ('the', 'DT'), ('pug', 'NN'), ('2016', 'CD'), ('wall', 'NN'), ('calendar', 'NN')], [('moleskine', 'NN'), ('2016', 'CD'), ('weekly', 'JJ'), ('notebook', 'NN'), ('12m', 'CD'), ('large', 'JJ'), ('black', 'JJ'), ('soft', 'JJ'), ('cover', 'NN'), ('5', 'CD'), ('x', 'JJ'), ('825', 'CD')], [('365', 'CD'), ('cats', 'NNS'), ('color', 'VBP'), ('pageaday', 'IN'), ('calendar', 'NN'), ('2016', 'CD')], [('sierra', 'NN'), ('club', 'NN'), ('engagement', 'NN'), ('calendar', 'NN'), ('2016', 'CD')], [('sierra', 'NN'), ('club', 'NN'), ('wilderness', 'NN'), ('calendar', 'NN'), ('2016', 'CD')]]

# %% [markdown]
# ## Named Entity Recognition (NER)
#
# Create list of lists with words, correspondent POS and named entity tags for each title (uses postags created in previous step)

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk import ne_chunk
from nltk.chunk import tree2conlltags

ner = []
for title in titles1:
    ner.append(tree2conlltags(ne_chunk(pos_tag(word_tokenize(title)))))
    
print(ner[0:5]) # test whether NER worked
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/feliciaheilgendorff/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/feliciaheilgendorff/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-f1b695e391f7> in <module>
#       6 ner = []
#       7 for title in titles1:
# ----> 8     ner.append(tree2conlltags(ne_chunk(pos_tag(word_tokenize(title)))))
#       9
#      10 print(ner[0:5]) # test whether NER worked
#
# NameError: name 'pos_tag' is not defined

# %% [markdown]
# # Classifiers
#
# Check whether stemming/lemmatization make difference in final classifiers
# -> does it improve/worsen classifier?
#
#
# -Naive Bayes (bag-of-words)
#
# -BERT (language model)
#
# https://towardsdatascience.com/text-classification-with-nlp-tf-idf-vs-word2vec-vs-bert-41ff868d1794

# %%
# First step: make third column in original dataframe for cleaned titles 
# (could have columns for stemmed/lemmatized etc versions)
# Columns: tokens, bigrams, trigrams, stems, lemmas, NER (this includes POS)

# %%
# create dataframe containing tokenized titles and genres
tok_title = pd.DataFrame({0: tokenized_titles})
data_in = [tok_title[0], df1["genre"]]
headers = ["titles", "genres"]

data = pd.concat(data_in, axis=1, keys=headers)
print(data[:5])
# Out:
#                                               titles     genres
# 0               [moms, family, wall, calendar, 2016]  Calendars
# 1             [doug, the, pug, 2016, wall, calendar]  Calendars
# 2  [moleskine, 2016, weekly, notebook, 12m, large...  Calendars
# 3       [365, cats, color, pageaday, calendar, 2016]  Calendars
# 4         [sierra, club, engagement, calendar, 2016]  Calendars

# %%
# split data into train and test
import numpy as np

test_pct=0.2 # split into 80/20%

# create mask
mask = np.random.choice([0, 1], p=[1 - test_pct, test_pct], size=data.shape[0])

# apply mask
data["mask"] = mask
test = data[data["mask"] == 1]
train = data[data["mask"] == 0]

# removing column
test = test.drop("mask", axis="columns").reset_index()
train = train.drop("mask", axis="columns").reset_index()

# remove original indexing data (otherwise we have double indexing)
test = test.drop("index", axis="columns")
train = train.drop("index", axis="columns")

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
from collections import Counter

# %%
# token frequencies within each title
unigram_count = []
for title in tokenized_titles:
    uni_title = Counter()
    for i in title:
        uni_title[i] += 1
    unigram_count.append(uni_title)

print(unigram_count[:5]) # test
# Out:
# [Counter({'moms': 1, 'family': 1, 'wall': 1, 'calendar': 1, '2016': 1}), Counter({'doug': 1, 'the': 1, 'pug': 1, '2016': 1, 'wall': 1, 'calendar': 1}), Counter({'moleskine': 1, '2016': 1, 'weekly': 1, 'notebook': 1, '12m': 1, 'large': 1, 'black': 1, 'soft': 1, 'cover': 1, '5': 1, 'x': 1, '825': 1}), Counter({'365': 1, 'cats': 1, 'color': 1, 'pageaday': 1, 'calendar': 1, '2016': 1}), Counter({'sierra': 1, 'club': 1, 'engagement': 1, 'calendar': 1, '2016': 1})]

# %%
# token frequencies in total vocab
tok_freq = Counter()
for title in train['titles']:
    for i in title:
        tok_freq[i] += 1
        
print(tok_freq)
# Out:
# Counter({'the': 92268, 'and': 54186, 'of': 51054, 'a': 31305, 'to': 27842, 'for': 21276, 'in': 21081, 'guide': 16004, 'edition': 12519, 'book': 8112, 'with': 7764, 'your': 7356, 'from': 6516, 'series': 6286, 'on': 5895, 'how': 5860, 'an': 5138, 'new': 4765, 'life': 4679, 'world': 4007, 'volume': 3992, 'history': 3984, 'you': 3801, '1': 3301, 'recipes': 3169, 'by': 3163, 'american': 2999, 'travel': 2912, 'complete': 2786, 'law': 2710, '2': 2682, 'story': 2615, 'art': 2585, 'handbook': 2547, 'health': 2528, 'my': 2503, 'books': 2378, 'science': 2257, 'calendar': 2185, 'at': 2174, 'best': 2079, 'novel': 2034, 'i': 1985, 'practice': 1977, 'guides': 1926, 'map': 1902, 'cookbook': 1886, 'that': 1861, 'vol': 1799, 'about': 1796, '2016': 1766, 'love': 1765, 'what': 1753, 'great': 1713, 'stories': 1669, 'business': 1653, 'more': 1639, 'war': 1632, 'it': 1626, 'is': 1608, 'one': 1571, 'introduction': 1567, 'modern': 1549, 'manual': 1544, 'second': 1519, 'management': 1518, 'america': 1510, 'food': 1497, 'first': 1494, 'study': 1488, 'all': 1486, 'spanish': 1482, 'other': 1480, '3': 1474, 'bible': 1458, 'through': 1451, 'easy': 1441, 'home': 1429, 'studies': 1413, 'care': 1409, 'library': 1406, 'living': 1391, 'design': 1390, 'day': 1378, 'kids': 1368, '2nd': 1339, 'practical': 1327, 'city': 1326, 'family': 1316, 'classics': 1302, 'techniques': 1286, 'time': 1285, 'who': 1274, 'national': 1244, 'essential': 1228, 'journey': 1191, 'power': 1182, 'school': 1168, '2015': 1161, 'english': 1158, 'know': 1151, 'secrets': 1140, 'way': 1137, 'making': 1135, 'ultimate': 1127, 'de': 1121, 'can': 1118, 'little': 1111, 'international': 1109, 'women': 1107, 'our': 1097, 'children': 1091, 'people': 1080, 'wall': 1078, 'culture': 1072, 'approach': 1068, 'god': 1065, 'pocket': 1064, 'diet': 1061, 'test': 1048, 'review': 1042, 'true': 1028, 'make': 1026, 'theory': 1025, 'exam': 1021, 'game': 1014, '100': 1012, 'or': 1010, 'big': 1008, 'social': 1003, 'collection': 1000, 'nursing': 995, 'illustrated': 994, 'set': 991, 'no': 984, 'heart': 971, 'classic': 965, 'cooking': 963, 'understanding': 960, 'medical': 956, 'black': 955, 'atlas': 951, 'coloring': 950, 'principles': 945, 'most': 943, 'worlds': 939, 'revised': 938, 'do': 934, '4': 934, 'planet': 928, 'healthy': 922, 'us': 915, 'human': 914, 'sports': 908, 'natural': 908, 'into': 905, 'as': 901, 'clinical': 901, 'learning': 892, 'workbook': 887, 'years': 881, 'reference': 879, 'analysis': 879, 'its': 876, 'ancient': 872, 'simple': 862, 'me': 856, 'their': 852, 'be': 847, 'work': 837, 'real': 835, 'man': 831, 'out': 829, '5': 824, 'development': 824, 'good': 822, 'country': 820, 'get': 818, 'medicine': 817, 'strategies': 817, 'up': 814, 'research': 812, 'dummies': 811, 'encyclopedia': 810, 'third': 800, 'two': 796, 'everything': 795, 'lonely': 794, 'healing': 794, 'why': 792, 'north': 790, 'body': 790, 'south': 785, 'official': 779, 'system': 775, '3rd': 774, 'tales': 767, 'over': 767, 'dover': 766, 'secret': 765, 'using': 764, 'dictionary': 756, 'writing': 754, 'when': 752, 'beyond': 749, 'every': 736, 'legal': 733, 'systems': 729, 'journal': 726, 'building': 724, 'age': 723, 'not': 720, 'language': 719, 'applications': 719, 'we': 717, 'adventures': 712, 'are': 711, 'skills': 704, 'ii': 701, 'year': 698, 'student': 698, 'need': 693, 'weight': 692, 'child': 691, 'professional': 691, 'french': 689, 'beginners': 689, 'adventure': 687, 'maps': 685, 'questions': 680, '10': 675, 'young': 673, 'free': 673, '2013': 668, 'house': 666, 'success': 666, 'la': 666, 'oxford': 666, 'training': 665, 'high': 663, 'advanced': 661, 'change': 655, 'century': 653, 'his': 650, 'level': 649, 'days': 648, '50': 648, 'street': 647, 'inside': 647, 'global': 644, 'made': 644, 'basic': 644, 'therapy': 643, 'essentials': 641, 'things': 638, 'contemporary': 637, 'garden': 634, 'politics': 632, 'mind': 630, 'physics': 630, 'program': 629, 'technology': 626, 'chemistry': 625, 'christmas': 623, 'veterinary': 623, 'delicious': 622, 'road ...

# %%
# group data by genre

grouped = train.groupby(train.genres)

Calendars = grouped.get_group("Calendars")
Comics = grouped.get_group("Comics & Graphic Novels")
Test = grouped.get_group("Test Preparation")
Mystery = grouped.get_group("Mystery, Thriller & Suspense")
SciFi = grouped.get_group("Science Fiction & Fantasy")
Romance = grouped.get_group("Romance")
Humor = grouped.get_group("Humor & Entertainment")
Literature = grouped.get_group("Literature & Fiction")
LGBTQ = grouped.get_group("Gay & Lesbian")
Engineering = grouped.get_group("Engineering & Transportation")
Food = grouped.get_group("Cookbooks, Food & Wine")
Crafts = grouped.get_group("Crafts, Hobbies & Home")
Arts = grouped.get_group("Arts & Photography")
Education = grouped.get_group("Education & Teaching")
Parenting = grouped.get_group("Parenting & Relationships")
SelfHelp = grouped.get_group("Self-Help")
Computers = grouped.get_group("Computers & Technology")
Medical = grouped.get_group("Medical Books")
Science = grouped.get_group("Science & Math")
Health = grouped.get_group("Health, Fitness & Dieting")
Business = grouped.get_group("Business & Money")
Law = grouped.get_group("Law")
Biographies = grouped.get_group("Biographies & Memoirs")
History = grouped.get_group("History")
Politics = grouped.get_group("Politics & Social Sciences")
Reference = grouped.get_group("Reference")
Bibles = grouped.get_group("Christian Books & Bibles")
Religion = grouped.get_group("Religion & Spirituality")
Sports = grouped.get_group("Sports & Outdoors")
Teen = grouped.get_group("Teen & Young Adult")
Childrens = grouped.get_group("Children's Books")
Travel = grouped.get_group("Travel")

GenreGroups = [Calendars['titles'], Comics['titles'], Test['titles'], Mystery['titles'], SciFi['titles'], 
               Romance['titles'], Humor['titles'], Literature['titles'], LGBTQ['titles'], Engineering['titles'], 
               Food['titles'], Crafts['titles'], Arts['titles'], Education['titles'], Parenting['titles'], 
               SelfHelp['titles'], Computers['titles'], Medical['titles'], Science['titles'], Health['titles'], 
               Business['titles'], Law['titles'], Biographies['titles'], History['titles'], Politics['titles'], 
               Reference['titles'], Bibles['titles'], Religion['titles'], Sports['titles'], Teen['titles'], 
               Childrens['titles'], Travel['titles']]

# %%
# token frequencies in each genre
keys = ['Calendars', 'Comics & Graphic Novels', 'Test Preparation',
       'Mystery, Thriller & Suspense', 'Science Fiction & Fantasy',
       'Romance', 'Humor & Entertainment', 'Literature & Fiction',
       'Gay & Lesbian', 'Engineering & Transportation',
       'Cookbooks, Food & Wine', 'Crafts, Hobbies & Home',
       'Arts & Photography', 'Education & Teaching',
       'Parenting & Relationships', 'Self-Help', 'Computers & Technology',
       'Medical Books', 'Science & Math', 'Health, Fitness & Dieting',
       'Business & Money', 'Law', 'Biographies & Memoirs', 'History',
       'Politics & Social Sciences', 'Reference',
       'Christian Books & Bibles', 'Religion & Spirituality',
       'Sports & Outdoors', 'Teen & Young Adult', "Children's Books",
       'Travel']

genre_count = []
for g in GenreGroups:
    genre_title = Counter()
    for title in g:
        for i in title:
            genre_title[i] += 1
    genre_count.append(genre_title)

# %%
# combine keys and titles grouped by genres
zipped_values = zip(keys, genre_count)
tok_freq_genres = list(zipped_values)

# %%
tok_freq_genres[0][1]
# Out:
# Counter({'moms': 12,
#          'family': 13,
#          'wall': 810,
#          'calendar': 1967,
#          '2016': 1126,
#          'doug': 1,
#          'the': 367,
#          'pug': 3,
#          'moleskine': 26,
#          'weekly': 57,
#          'notebook': 18,
#          '12m': 7,
#          'large': 23,
#          'black': 25,
#          'soft': 8,
#          'cover': 28,
#          '5': 13,
#          'x': 26,
#          '825': 13,
#          '365': 71,
#          'cats': 39,
#          'color': 12,
#          'pageaday': 56,
#          'sierra': 3,
#          'club': 5,
#          'engagement': 66,
#          'wilderness': 8,
#          'thomas': 10,
#          'kinkade': 9,
#          'disney': 20,
#          'dreams': 4,
#          'collection': 10,
#          'ansel': 2,
#          'adams': 2,
#          'dilbert': 5,
#          'daytoday': 95,
#          'mary': 9,
#          'engelbreit': 6,
#          'deluxe': 34,
#          'never': 2,
#          'give': 1,
#          'up': 7,
#          'cat': 29,
#          'gallery': 11,
#          'llewellyns': 4,
#          'witches': 2,
#          'datebook': 2,
#          'amy': 3,
#          'knapp': 2,
#          'big': 9,
#          'grid': 3,
#          'essential': 1,
#          'organization': 1,
#          'and': 136,
#          'communication': 1,
#          'tool': 1,
#          'for': 59,
#          'entire': 1,
#          'audubon': 6,
#          'nature': 13,
#          'national': 18,
#          'park': 2,
#          'foundation': 1,
#          'your': 13,
#          'year': 47,
#          'mindful': 3,
#          'coloring': 11,
#          'through': 30,
#          'seasons': 3,
#          'enjoy': 1,
#          'joy': 1,
#          'grumpy': 2,
#          'extra': 3,
#          '75': 3,
#          '10': 3,
#          'pocket': 47,
#          '35': 7,
#          '55': 7,
#          'dogs': 7,
#          'dog': 26,
#          'maxine': 6,
#          'yearinabox': 7,
#          'descendants': 1,
#          'walking': 1,
#          'dead': 1,
#          'complete': 6,
#          'runners': 3,
#          'daybyday': 2,
#          'log': 5,
#          'astrological': 1,
#          '83rd': 1,
#          'edition': 126,
#          'of': 217,
#          'worlds': 7,
#          'best': 5,
#          'known': 1,
#          'most': 6,
#          'trusted': 1,
#          'astrology': 1,
#          'today': 2,
#          'is': 12,
#          'going': 2,
#          'to': 42,
#          'be': 4,
#          'a': 95,
#          'great': 17,
#          'day': 29,
#          'french': 21,
#          'country': 22,
#          'diary': 16,
#          'pusheen': 2,
#          'posh': 8,
#          'fun': 5,
#          'relaxation': 1,
#          'planner': 88,
#          'smile': 1,
#          'its': 6,
#          'good': 5,
#          'you': 9,
#          'old': 6,
#          'farmers': 6,
#          'almanac': 10,
#          'gardening': 7,
#          'monthly': 82,
#          'just': 45,
#          'being': 2,
#          'me': 3,
#          'someecards': 1,
#          'daily': 46,
#          'desktop': 10,
#          'almond': 1,
#          'blossoms': 1,
#          '16month': 37,
#          'new': 27,
#          'wordsayear': 3,
#          'song': 1,
#          'ice': 1,
#          'fire': 5,
#          'anne': 6,
#          'taintor': 1,
#          '20152016': 22,
#          '18m': 10,
#          'legend': 1,
#          'zelda': 2,
#          'once': 1,
#          'upon': 1,
#          'time': 9,
#          'sloths': 1,
#          'blue': 5,
#          'little': 8,
#          'world': 33,
#          'liz': 2,
#          'climo': 2,
#          'shoes': 2,
#          'orange': 8,
#          'circle': 7,
#          'studio': 11,
#          '17month': 5,
#          'do': 8,
#          'it': 9,
#          'all': 5,
#          'magnetic': 7,
#          'celestial': 4,
#          'wells': 1,
#          'street': 3,
#          'by': 122,
#          'lang': 11,
#          'planit': 1,
#          'plus': 1,
#          'august': 3,
#          '2015': 378,
#          'december': 28,
#          '12': 8,
#          '265': 1,
#          'inches': 1,
#          '7009167': 1,
#          'cynthia': 1,
#          'harts': 1,
#          'victoriana': 1,
#          'le': 1,
#          'petit': 1,
#          'prince': 1,
#          'limited': 8,
#          'hard': 17,
#          'john': 4,
#          'sloanes': 1,
#          'away': 3,
#          'charles': 4,
#          'wysocki': 2,
#          'americana': 1,
#          'super': 4,
#          'mario': 5,
#          'brothers': 4,
#          'supernatural': 3,
#          'jeopardy': 2,
#          'nightmare': 2,
#          'before': 6,
#          'christmas': 12,
#          'bad': 5,
#          'organizer': 1,
#          'out': 6,
#          'on': 22,
#          'porch': 1,
#          '1000': 1,
#          'places': 3,
#          'see': 1,
#          'die': 2,
#          'inner': 2,
#          'reflections': 2,
#          'secret': 3,
#          'garden': 46,
#          'book': 22,
#          'lovers': 14,
#          'downton': 5,
#          'abbey': 5,
#          'sugar': 3,
#          'skulls': 1,
#          'outlander': 1,
#          'boxeddaily': 20,
#          'collectible': 4,
#          'teapot': 4,
#          'tea': 4,
#          'animation': 2,
#          'art': 57,
#          'star': 42,
#          'trek': 14,
#          'ships': 18,
#          'line': 7,
#          'bible': 8,
#          'versesayear': 1,
#          'dc': 2,
#          'bombshells': 1,
#          'original': 9,
#          'sudoku': 19,
#          'retro': 3,
#          'days': 36,
#          'jewish': 4,
#          '5776': 1,
#          'manager': 3,
#          '17': 8,
#          'month': 88,
#          'peanuts': 9,
#          'islands': 2,
#          'mystique': 1,
#          'xposed': 1,
#          'adult': 2,
#          'mystic': 1,
#          'playboy': 1,
#          'girls': 5,
#          'penthouse': 1,
#          'vixens': 1,
#          'nude': 4,
#          'naked': 1,
#          'hot': 5,
#          'sexy': 3,
#          'chases': 1,
#          'events': 5,
#          'ultimate': 10,
#          'goto': 1,
#          'guide': 8,
#          'special': 6,
#          'weeks': 2,
#          'months': 2,
#          'hebrew': 1,
#          'illuminations': 1,
#          'series': 15,
#          'gooseberry': 10,
#          'patch': 10,
#          'calendars': 126,
#          'shaming': 2,
#          'wet': 1,
#          'gary': 6,
#          'pattersons': 4,
#          'unlikely': 1,
#          'friendships': 1,
#          'songbirds': 1,
#          'other': 1,
#          'backyard': 1,
#          'birds': 9,
#          'pictureaday': 7,
#          'butterflies': 5,
#          '18month': 7,
#          'catsbr': 1,
#          'kittensayear': 1,
#          'dogma2016': 1,
#          'baby': 3,
#          'goats': 1,
#          'september': 26,
#          'wildflowers': 6,
#          'extraordinary': 3,
#          'chickens': 3,
#          'yoga': 11,
#          'square': 175,
#          '12x12': 136,
#          'multilingual': 83,
#          'lil': 1,
#          'bub': 1,
#          'mini': 131,
#          'hedgehogs': 2,
#          'what': 9,
#          'teach': 8,
#          'us': 12,
#          'space': 7,
#          'we': 3,
#          'love': 11,
#          'william': 5,
#          'wegman': 1,
#          'puppies': 26,
#          'pembroke': 1,
#          'corgis': 1,
#          'adorable': 1,
#          'zen': 4,
#          'kindred': 1,
#          'trout': 1,
#          'north': 1,
#          'america': 4,
#          'desk': 32,
#          'pad': 7,
#          'mugs': 1,
#          'lesley': 4,
#          'harrison': 2,
#          'spirit': 12,
#          'horses': 45,
#          'wolf': 1,
#          'guys': 2,
#          'animals': 2,
#          'kittens': 10,
#          'dachshund': 3,
#          'rules': 2,
#          'tales': 1,
#          'i': 8,
#          'regret': 1,
#          'nothing': 1,
#          'animal': 14,
#          'memes': 1,
#          'boston': 1,
#          'terriers': 6,
#          'gypsy': 3,
#          'vanner': 3,
#          'horse': 26,
#          'goldendoodles': 1,
#          'texts': 1,
#          'from': 36,
#          'wisdom': 16,
#          'vs': 1,
#          'human': 1,
#          'in': 49,
#          'golden': 7,
#          'retriever': 3,
#          'lurcher': 2,
#          'breed': 11,
#          'specific': 8,
#          'avonside': 46,
#          'labs': 3,
#          'cartoona': 1,
#          'furbulous': 1,
#          'feline': 1,
#          'funnies': 1,
#          '13': 1,
#          'mysteries': 1,
#          'january': 1,
#          'joker': 1,
#          'february': 1,
#          'friend': 1,
#          'march': 1,
#          'mischief': 1,
#          'april': 1,
#          'adventure': 3,
#          'may': 1,
#          'magic': 5,
#          'june': 1,
#          'jam': 1,
#          'july': 2,
#          'jitters': 1,
#          'acrobat': 1,
#          'sneakers': 1,
#          'october': 1,
#          'ogre': 1,
#          'november': 1,
#          'night': 4,
#          'years': 4,
#          'eve': 1,
#          'thieves': 1,
#          'dachshunds': 6,
#          'owls': 2,
#          'debbie': 1,
#          'mumm': 1,
#          'checkbook2': 2,
#          '1986': 1,
#          'geographic': 8,
#          'waterfowl': 1,
#          '2014': 151,
#          'owl': 2,
#          'forest': 3,
#          'bunny': 2,
#          'suicides': 1,
#          'yorkies': 1,
#          'happy': 2,
#          'at': 12,
#          'box': 14,
#          'bulldogs': 4,
#          'maine': 6,
#          'coon': 3,
#          'naps': 5,
#          'mysadcat': 1,
#          'tuxedo': 2,
#          '7x7': 25,
#          'ivory': 5,
#          '11x14': 16,
#          'why': 3,
#          'that': 14,
#          'could': 1,
#          'pee': 1,
#          'this': 5,
#          'dancing': 1,
#          'proverbial': 1,
#          'down': 4,
#          'east': 4,
#          'siamese': 3,
#          'garfield': 2,
#          'kitties': 1,
#          'personal': 5,
#          '22016': 1,
#          'simons': 1,
#          'kitten': 4,
#          'magnum': 10,
#          'twoyear': 5,
#          'persian': 2,
#          'cuddles': 1,
#          'burmese': 1,
#          'hats': 1,
#          'paintings': 2,
#          'whiskerslist': 1,
#          'sueellen': 1,
#          'ross': 1,
#          'rachael': 1,
#          'hale': 1,
#          'angry': 1,
#          'ginger': 1,
#          'dogma': 2,
#          'boo': 3,
#          'bulldog': 2,
#          'chihuahua': 1,
#          'border': 2,
#          'terrier': 1,
#          'retrievers': 4,
#          'collies': 2,
#          'pomeranians': 1,
#          'shelties': 1,
#          'boxer': 1,
#          'westies': 1,
#          'german': 17,
#          'shepherds': 4,
#          'american': 45,
#          'kennel': 1,
#          'poodles': 2,
#          'miniature': 2,
#          'schnauzers': 1,
#          'basset': 2,
#          'hounds': 1,
#          'shepherd': 1,
#          'shorthaired': 1,
#          'pointers': 1,
#          'boys': 3,
#          'beagle': 3,
#          'shih': 2,
#          'tzu': 2,
#          'chocolate': 3,
#          'only': 4,
#          'pugs': 3,
#          'rottweilers': 1,
#          'yellow': 3,
#          'australian': 1,
#          'scottish': 3,
#          'greyhounds': 1,
#          'maltese': 1,
#          'bernese': 1,
#          'mountain': 5,
#          'siberian': 3,
#          'husky': 3,
#          'lab': 1,
#          'eskimo': 1,
#          'eskimos': 1,
#          'pooped': 2,
#          'cairn': 1,
#          'hound': 2,
#          'labradoodle': 2,
#          'schnauzer': 1,
#          'mastiff': 2,
#          'collie': 2,
#          'wheaten': 1,
#          'coated': 1,
#          'shiba': 3,
#          'inu': 3,
#          'toy': 1,
#          'shetland': 3,
#          'sheepdog': 2,
#          'underwater': 1,
#          'welsh': 1,
#          'corgi': 1,
#          'watercolor': 1,
#          'happiness': 5,
#          'quarter': 3,
#          'portrait': 2,
#          'painted': 1,
#          'ponies': 4,
#          'arabians': 2,
#          'feathers': 1,
#          'paint': 2,
#          'spirited': 1,
#          'western': 2,
#          'clydesdales': 1,
#          '160640': 1,
#          'english': 19,
#          'spanish': 20,
#          'italian': 14,
#          '20162017': 6,
#          '2': 17,
#          'arabian': 2,
#          'wyman': 13,
#          'racing': 3,
#          'wild': 31,
#          'dressage': 1,
#          '366': 3,
#          'mustangs': 1,
#          'west': 1,
#          'stephen': 1,
#          'king': 2,
#          '2006': 7,
#          'includes': 5,
#          'short': 1,
#          'story': 3,
#          'my': 9,
#          'pretty': 3,
#          'pony': 1,
#          'cowgirls': 1,
#          '161537': 1,
#          '13x14': 1,
#          'mist': 2,
#          'sense': 1,
#          'dreaming': 1,
#          'poster': 22,
#          'helma': 9,
#          'graphique': 2,
#          'slim': 6,
#          'photographs': 13,
#          'tony': 1,
#          'stromberg': 1,
#          'doubleview': 2,
#          'easel': 7,
#          'haunted': 1,
#          'realm': 2,
#          'tree': 2,
#          'houses': 3,
#          'castles': 5,
#          'lighthouses': 69,
#          'skyscrapers': 1,
#          'buildings': 2,
#          'barns': 2,
#          'things': 8,
#          'come': 3,
#          'apart': 2,
#          'farm': 2,
#          'doors': 1,
#          'windows': 1,
#          'hundertwasser': 2,
#          'architecture': 10,
#          'master': 3,
#          'drawings': 4,
#          'frank': 13,
#          'lloyd': 7,
#          'wright': 6,
#          'treehouses': 5,
#          'outhouses': 5,
#          '2004': 4,
#          'washington': 1,
#          'road': 1,
#          'home': 6,
#          'designs': 4,
#          'nashville': 2,
#          '12month': 15,
#          'featuring': 23,
#          'wonderful': 7,
#          'photography': 9,
#          'write': 2,
#          'key': 2,
#          'italia': 1,
#          'landmarks': 2,
#          'with': 32,
#          'scripture': 5,
#          'vine': 2,
#          'publications': 2,
#          'atlantic': 3,
#          'coast': 8,
#          'england': 5,
#          'dã¼sseldorf': 1,
#          'timeless': 3,
#          'visions': 1,
#          'chicago': 2,
#          'sports': 25,
#          'venues': 1,
#          'bridges': 2,
#          '2013': 100,
#          'wrights': 1,
#          'dream': 8,
#          'broschã¼renkalender': 1,
#          'gaudi': 1,
#          'cottages': 3,
#          'herb': 2,
#          'ritts': 1,
#          '1996': 1,
#          'lighthouse': 17,
#          '2012': 59,
#          'norman': 2,
#          'rockwell': 2,
#          'saturday': 2,
#          'evening': 2,
#          'post': 2,
#          'lakes': 5,
#          'architectu': 1,
#          'germany': 2,
#          'paris': 5,
#          'glitz': 1,
#          'georgia': 5,
#          'okeeffe': 1,
#          'enchanted': 3,
#          'tiffany': 1,
#          'taschen': 3,
#          '2011': 33,
#          'tractors': 3,
#          'york': 12,
#          'irish': 3,
#          'pubs': 1,
#          'hardcover': 2,
#          'colt': 1,
#          'leather': 1,
#          'charley': 1,
#          'harper': 1,
#          'susan': 4,
#          'branch': 4,
#          'blotter': 1,
#          'painter': 3,
#          'light': 3,
#          'collectors': 5,
#          'majesty': 2,
#          'masterpieces': 1,
#          'chihuly': 1,
#          'attitude': 1,
#          'everything': 1,
#          'advent': 20,
#          'bless': 1,
#          'destress': 1,
#          'season': 1,
#          'edward': 6,
#          'gorey': 1,
#          'painters': 4,
#          'floral': 5,
#          'planning': 6,
#          'fantasy': 7,
#          'luis': 1,
#          'royo': 1,
#          'masha': 1,
#          'dyans': 1,
#          'tokidoki': 1,
#          'simplicity': 6,
#          'private': 1,
#          'presents': 5,
#          'totally': 2,
#          'chick': 1,
#          'girl': 5,
#          'women': 15,
#          'myth': 1,
#          'environmental': 1,
#          'contemporary': 1,
#          'natural': 1,
#          'bev': 2,
#          'doolittlebrbr': 1,
#          'impressionism': 3,
#          'postimpressionism': 2,
#          'lotta': 1,
#          'jansdotter': 1,
#          'cobblestone': 1,
#          'way': 7,
#          'lets': 1,
#          'pretend': 1,
#          'happened': 1,
#          'david': 1,
#          'olenick': 1,
#          'parks': 4,
#          'classic': 28,
#          'posters': 3,
#          'land': 1,
#          'creations': 1,
#          'quilt': 26,
#          'engagment': 2,
#          'broadway': 1,
#          'gardens': 28,
#          'grace': 4,
#          'soul': 2,
#          'mc': 1,
#          'escher': 1,
#          'place': 10,
#          'studs': 1,
#          'n': 1,
#          'spurs': 1,
#          'kim': 1,
#          'parker': 1,
#          'perpetual': 34,
#          'redstone': 2,
#          'therapeutic': 1,
#          'books': 3,
#          'holly': 1,
#          'randalls': 1,
#          'hotties': 1,
#          'lingerie': 2,
#          'kitchen': 5,
#          'geo': 1,
#          'tribe': 1,
#          'patterns': 4,
#          'spiral': 7,
#          'chalk': 3,
#          'inuit': 2,
#          'artcape': 1,
#          'dorset': 2,
#          'small': 2,
#          'untroubled': 1,
#          'gustave': 2,
#          'baumann': 2,
#          'hyperbole': 3,
#          'half': 3,
#          'sara': 1,
#          'steele': 1,
#          'originals': 1,
#          'illusion': 1,
#          'serenity': 3,
#          'chippendales': 1,
#          'calen': 1,
#          'bike': 2,
#          'bicycle': 1,
#          'movie': 9,
#          'film': 1,
#          'registry': 1,
#          'library': 2,
#          'congress': 1,
#          'keith': 2,
#          'haring': 1,
#          'engelbreits': 1,
#          'can': 2,
#          'anything': 1,
#          '201516': 1,
#          'coffee': 7,
#          'supercars': 2,
#          'cars': 27,
#          'farmall': 2,
#          'tractor': 1,
#          'muscle': 6,
#          'porsche': 2,
#          'car': 14,
#          'automobile': 12,
#          'trucks': 6,
#          'action': 5,
#          '16': 69,
#          'corvette': 9,
#          'caterpillar': 1,
#          'stsilver': 2,
#          'foil': 5,
#          'ferrari': 4,
#          'sting': 2,
#          'ray': 2,
#          'caraday': 2,
#          'volkswagen': 1,
#          'bus': 1,
#          'motorcycle': 3,
#          'mustang': 4,
#          'monster': 3,
#          'pixar': 3,
#          'camaro': 4,
#          'ford': 5,
#          '17x12': 2,
#          'print': 4,
#          '1970': 1,
#          'boss': 2,
#          '302': 1,
#          '1966': 1,
#          'l72': 1,
#          'convertible': 1,
#          'aston': 1,
#          'martin': 1,
#          'james': 1,
#          'bond': 1,
#          'official': 104,
#          'gt': 1,
#          'classics': 7,
#          'automobiles': 2,
#          'plato': 1,
#          'vintage': 24,
#          'citroen': 1,
#          'dodge': 1,
#          'charger': 1,
#          'british': 6,
#          'f1': 2,
#          '30x30cm': 1,
#          'mg': 1,
#          'vw': 3,
#          'campers': 2,
#          'pontiac': 1,
#          'gto': 2,
#          'trucker': 1,
#          'beetle': 1,
#          'stred': 1,
#          'harleydavidson': 1,
#          'dayatatime': 1,
#          'fiat': 1,
#          '500': 1,
#          'pickups': 2,
#          'exif': 1,
#          'custom': 3,
#          'sons': 1,
#          'anarchy': 1,
#          'speed': 1,
#          'race': 1,
#          'cruisin': 1,
#          'chrome': 1,
#          'motorsport': 1,
#          'including': 1,
#          'superbikes': 3,
#          'danica': 1,
#          'patrick': 1,
#          'motor': 1,
#          'boats': 18,
#          'sailing': 25,
#          'harbors': 2,
#          'wooden': 12,
#          'tall': 11,
#          'mark': 2,
#          'sailor': 2,
#          'moon': 3,
#          'wandkalender': 2,
#          'photoart': 1,
#          'kalender': 1,
#          'seven': 4,
#          'seas': 4,
#          'sailors': 4,
#          'thirtyfirst': 1,
#          'sail': 2,
#          'chriscraft': 1,
#          'power': 3,
#          'wind': 2,
#          'trip': 1,
#          'an': 4,
#          'lifetime': 1,
#          'calvendo': 1,
#          'japanese': 9,
#          'anime': 1,
#          'guardian': 1,
#          'bishojo': 1,
#          'senshi': 1,
#          'crystal': 2,
#          'cruising': 3,
#          'around': 4,
#          'words': 12,
#          'dr': 5,
#          'crash': 3,
#          'oceanliners': 2,
#          'media': 7,
#          'illustration': 8,
#          '2010': 19,
#          'motorboats': 2,
#          '2009': 18,
#          'executive': 2,
#          'j': 3,
#          'levine': 1,
#          '5772': 1,
#          '2011december': 1,
#          'shipping': 1,
#          'now': 2,
#          'regatta': 1,
#          'simplysailing': 1,
#          'our': 4,
#          'voyage': 1,
#          'inspiring': 5,
#          'youth': 2,
#          '20132014': 1,
#          '3044612': 1,
#          'honor': 2,
#          'harrington': 2,
#          'fleet': 2,
#          '2007': 10,
#          'titanic': 1,
#          'mariners': 1,
#          '2008': 16,
#          'nautical': 1,
#          'ocean': 1,
#          'liners': 1,
#          'dancers': 2,
#          '51031': 1,
#          '2002': 9,
#          '2003': 4,
#          'boatsâ®': 1,
#          'harry': 14,
#          'potter': 14,
#          'tolkien': 10,
#          'winnie': 3,
#          'pooh': 3,
#          'lord': 8,
#          'rings': 8,
#          'trilogy': 2,
#          'wintervillage': 1,
#          'adventures': 2,
#          'odyssey': 2,
#          'activity': 6,
#          'countdown': 5,
#          'winters': 1,
#          'popup': 2,
#          'journey': 2,
#          'manger': 2,
#          'childrens': 1,
#          'cl53341': 1,
#          'elsa': 2,
#          'beskow': 2,
#          'puggle': 1,
#          'nutcracker': 1,
#          'set': 3,
#          'tintin': 1,
#          'caillou': 1,
#          'waits': 1,
#          'santa': 1,
#          'hello': 5,
#          'kitty': 4,
#          'woodland': 2,
#          'babies': 1,
#          'stickers': 2,
#          'sketch': 1,
#          'guess': 1,
#          'how': 3,
#          'much': 1,
#          'babys': 5,
#          'first': 7,
#          'abcs': 1,
#          'kids': 7,
#          'twas': 1,
#          'silent': 1,
#          'clocks': 1,
#          'marking': 1,
#          'millennium': 1,
#          'usa': 6,
#          'travel': 2,
#          'journal': 11,
#          'hiking': 1,
#          'angels': 3,
#          'carol': 1,
#          'workman': 2,
#          'undated': 2,
#          'diariesadvent': 1,
#          'nurse': 1,
#          'wtwosided': 1,
#          'incl': 1,
#          '201112': 1,
#          'class': 1,
#          'friends': 4,
#          'wrestling': 2,
#          'wwe': 4,
#          'a3': 13,
#          'sticker': 1,
#          'dover': 1,
#          'boxed': 10,
#          '50': 3,
#          'state': 6,
#          'children': 2,
#          'seuss': 1,
#          'deathly': 1,
#          'hallows': 1,
#          'griffin': 2,
#          'dragon': 5,
#          'week': 6,
#          'like': 3,
#          'stories': 3,
#          'entlebucher': 1,
#          'coton': 1,
#          'de': 2,
#          'tulear': 1,
#          'artwork': 3,
#          'postcard': 1,
#          'wishes': 1,
#          'paper': 4,
#          'pals': 1,
#          'doll': 1,
#          'jessie': 1,
#          'willcox': 1,
#          'smith': 1,
#          'cl53182': 1,
#          'illustrations': 1,
#          'grandpre': 1,
#          'goblet': 1,
#          'winniethepoohs': 1,
#          '2005': 5,
#          'fancy': 2,
#          'nancy': 2,
#          '1984': 1,
#          'jrr': 2,
#          ...})

# %%
# number of words in a class
len(tok_freq_genres[0][1]) # first genre
# Out:
# 2342

# %%
# class name
tok_freq_genres[0][0] # first genre
# Out:
# 'Calendars'

# %%
# number of total vocabulary (training set)
V = len(Counter(tok_freq))
print(V)
# Out:
# 35626

# %%
# number of titles (in training set)
N_titles = len(train)
print(N_titles)
# Out:
# 41399

# %%
# number of titles in each genre
N_genre = train['genres'].value_counts()
print(N_genre[:5])
# Out:
# Travel                       14605
# Children's Books             10868
# Medical Books                 9637
# Health, Fitness & Dieting     9492
# Business & Money              7985
# Name: genres, dtype: int64

# %%
N_genre['Travel'] # access number of titles in specified genre
# Out:
# 3594

# %%
# compute priors for each class
# total vocab = V
# number of words in each class -> token frequencies for each genre

for i in train['genres']:
    # count words within each document for all documents in class
    
# probabilities of title being in given genre
probabilities = []
for i in N_genre:
    probabilities = i / N_titles

# %%
# likelihoods for each word
# probability genre given word
# x = token frequencies for each genre -> saved as dictionary in tok_freq_genres[0][1] for first genre

# Nc = number of words in class
for i in tok_freq_genres[0][i]:
    len(tok_freq_genres[0][i]) # gives length of i-th genre
tok_freq_genres[0][0] # gives name of first genre
# V = total vocab

#(x+1) / (Nc + V)

# probability genre given word not in testset

# %%
# test NB using test data

# %% [markdown]
# ## BERT

# %%
# import relevant packages
import transformers

# do we need PyTorch / Tensorflow as well?
