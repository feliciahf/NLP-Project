# %% [markdown]
# <a href="https://colab.research.google.com/github/feliciahf/NLP-Project/blob/main/amazon/colab_FH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Naive Bayes from scratch

# %% [markdown]
# # Importing & Cleaning data
#
# This section imports the data into a pandas dataframe and goes through the following preprocessing steps:
#
# -Case collapsing
# -Remove punctuation
# -Tokenization
# -N-Grams: bigrams and trigrams
# -Stemming -> check whether this makes a difference
# -Lemmatization -> check whether this makes a difference
# -Part-of-speech (POS) tagging
# -Named entity recognition (NER)

# %% [markdown]
# ## Import Data
# We first import the data as a pandas dataframe. Then we create a list made up of the title and genre columns from the original data. We also create a list including all 32 genres.

# %% [markdown]
# In order to import the data into Google Colab, we have to first upload the csv file:

# %%
# mount Google Drive
from google.colab import  drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# import file from Google Drive
import pandas as pd
df = pd.read_csv('/drive/My Drive/book32listing.csv',encoding='latin1', header=None)

# %%
# drop columns that are not needed
#df = pd.read_csv("book32listing.csv", encoding='latin1', header=None)
df1 = df[[3,6]] # only columns with titles and genres
df1.columns = ['title', 'genre']
print(df1)
# Out:
#                                                     title      genre
# 0                         Mom's Family Wall Calendar 2016  Calendars
# 1                         Doug the Pug 2016 Wall Calendar  Calendars
# 2       Moleskine 2016 Weekly Notebook, 12M, Large, Bl...  Calendars
# 3                 365 Cats Color Page-A-Day Calendar 2016  Calendars
# 4                    Sierra Club Engagement Calendar 2016  Calendars
# ...                                                   ...        ...
# 207567  ADC the Map People Washington D.C.: Street Map...     Travel
# 207568  Washington, D.C., Then and Now: 69 Sites Photo...     Travel
# 207569  The Unofficial Guide to Washington, D.C. (Unof...     Travel
# 207570      Washington, D.C. For Dummies (Dummies Travel)     Travel
# 207571  Fodor's Where to Weekend Around Boston, 1st Ed...     Travel
#
# [207572 rows x 2 columns]

# %%
titles = df1['title'] # list of all titles
titles1 = titles.values.tolist() # change to list of strings
print(titles1[0:6]) # test whether it worked
# Out:
# ["Mom's Family Wall Calendar 2016", 'Doug the Pug 2016 Wall Calendar', 'Moleskine 2016 Weekly Notebook, 12M, Large, Black, Soft Cover (5 x 8.25)', '365 Cats Color Page-A-Day Calendar 2016', 'Sierra Club Engagement Calendar 2016', 'Sierra Club Wilderness Calendar 2016']

# %%
genres = df1['genre']
genres = genres.values.tolist()
genres = pd.DataFrame(genres)

# %%
df1.genre.unique() # list of all possible genres
# Out:
# array(['Calendars', 'Comics & Graphic Novels', 'Test Preparation',
#        'Mystery, Thriller & Suspense', 'Science Fiction & Fantasy',
#        'Romance', 'Humor & Entertainment', 'Literature & Fiction',
#        'Gay & Lesbian', 'Engineering & Transportation',
#        'Cookbooks, Food & Wine', 'Crafts, Hobbies & Home',
#        'Arts & Photography', 'Education & Teaching',
#        'Parenting & Relationships', 'Self-Help', 'Computers & Technology',
#        'Medical Books', 'Science & Math', 'Health, Fitness & Dieting',
#        'Business & Money', 'Law', 'Biographies & Memoirs', 'History',
#        'Politics & Social Sciences', 'Reference',
#        'Christian Books & Bibles', 'Religion & Spirituality',
#        'Sports & Outdoors', 'Teen & Young Adult', "Children's Books",
#        'Travel'], dtype=object)

# %% [markdown]
# ## Case Collapsing
# Change all uppercase to lowercase letters

# %%
case_collap = map(lambda x:x.lower(), titles1)
case_collap_list = list(case_collap)
print(case_collap_list[0:6])
# Out:
# ["mom's family wall calendar 2016", 'doug the pug 2016 wall calendar', 'moleskine 2016 weekly notebook, 12m, large, black, soft cover (5 x 8.25)', '365 cats color page-a-day calendar 2016', 'sierra club engagement calendar 2016', 'sierra club wilderness calendar 2016']

# %% [markdown]
# ## Remove Punctuation
# Remove punctuation by creating a translation table.
# Punctuation to be removed is given in string: string.punctuation

# %%
import string
trans = str.maketrans('', '', string.punctuation)
rem_punct = [s.translate(trans) for s in case_collap_list]
print(rem_punct[0:6])
# Out:
# ['moms family wall calendar 2016', 'doug the pug 2016 wall calendar', 'moleskine 2016 weekly notebook 12m large black soft cover 5 x 825', '365 cats color pageaday calendar 2016', 'sierra club engagement calendar 2016', 'sierra club wilderness calendar 2016']

# %% [markdown]
# ## Tokenization
# This splits all titles into words (output: list of lists of strings)

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokenized_titles = [word_tokenize(i) for i in rem_punct]
print(tokenized_titles[:10])
# Out:
# [['moms', 'family', 'wall', 'calendar', '2016'], ['doug', 'the', 'pug', '2016', 'wall', 'calendar'], ['moleskine', '2016', 'weekly', 'notebook', '12m', 'large', 'black', 'soft', 'cover', '5', 'x', '825'], ['365', 'cats', 'color', 'pageaday', 'calendar', '2016'], ['sierra', 'club', 'engagement', 'calendar', '2016'], ['sierra', 'club', 'wilderness', 'calendar', '2016'], ['thomas', 'kinkade', 'the', 'disney', 'dreams', 'collection', '2016', 'wall', 'calendar'], ['ansel', 'adams', '2016', 'wall', 'calendar'], ['dilbert', '2016', 'daytoday', 'calendar'], ['mary', 'engelbreit', '2016', 'deluxe', 'wall', 'calendar', 'never', 'give', 'up']]

# %% [markdown]
# # Classifier

# %% [markdown]
# ## Split data into train/test

# %% [markdown]
# In order to split the data into train and test sets, we create a dataframe containing the tokenized titles. We then split the data into 80% for training and 20% for testing.

# %%
# create dataframe containing tokenized titles and genres
tok_title = pd.DataFrame({0: tokenized_titles})
data_in = [tok_title[0], df1["genre"]]
headers = ["titles", "genres"]

data = pd.concat(data_in, axis=1, keys=headers)
print(data[:5])
# Out:
#                                               titles     genres
# 0               [moms, family, wall, calendar, 2016]  Calendars
# 1             [doug, the, pug, 2016, wall, calendar]  Calendars
# 2  [moleskine, 2016, weekly, notebook, 12m, large...  Calendars
# 3       [365, cats, color, pageaday, calendar, 2016]  Calendars
# 4         [sierra, club, engagement, calendar, 2016]  Calendars

# %%
# split data into train and test
import numpy as np

test_pct=0.2 # split into 80/20%

# create mask
mask = np.random.choice([0, 1], p=[1 - test_pct, test_pct], size=data.shape[0])

# apply mask
data["mask"] = mask
test = data[data["mask"] == 1]
train = data[data["mask"] == 0]

# removing column
test = test.drop("mask", axis="columns").reset_index()
train = train.drop("mask", axis="columns").reset_index()

# remove original indexing data (otherwise we have double indexing)
test = test.drop("index", axis="columns")
train = train.drop("index", axis="columns")

# %%
# save split datasets as csv files in Google Drive
test.to_csv('/drive/My Drive/test_NB.csv', index=False)
train.to_csv('/drive/My Drive/train_NB.csv', index=False)

## this gives error messages if next parts are done using csv files... so just saved for reference

# %% [markdown]
# ## Naive Bayes classifier
#
# We build the Naive Bayes classifier from scratch. In order to do this, we create lists of the following: token frequencies in total vocabulary, token frequencies in each genre, number of words in each genre, number of words in total vocabulary, number of total titles, number of titles in each genre. Using these, we compute the priors for each genre and the likelihoods for each word to be in any genre.
# Using both the priors and the likelihoods, we create a dataframe with prediction values. By taking the highest prediction value of a particular word across the genres, we can get the predicted genre for that word.
#
# We then test out whether the model works for the test data.

# %% [markdown]
# ### Train model: Prep

# %%
from collections import Counter

# %%
# token frequencies within each title (we don't need this...)
unigram_count = []
for title in tokenized_titles:
    uni_title = Counter()
    for i in title:
        uni_title[i] += 1
    unigram_count.append(uni_title)

print(unigram_count[:5]) # test
# Out:
# [Counter({'moms': 1, 'family': 1, 'wall': 1, 'calendar': 1, '2016': 1}), Counter({'doug': 1, 'the': 1, 'pug': 1, '2016': 1, 'wall': 1, 'calendar': 1}), Counter({'moleskine': 1, '2016': 1, 'weekly': 1, 'notebook': 1, '12m': 1, 'large': 1, 'black': 1, 'soft': 1, 'cover': 1, '5': 1, 'x': 1, '825': 1}), Counter({'365': 1, 'cats': 1, 'color': 1, 'pageaday': 1, 'calendar': 1, '2016': 1}), Counter({'sierra': 1, 'club': 1, 'engagement': 1, 'calendar': 1, '2016': 1})]

# %%
# token frequencies in total vocab
tok_freq = Counter()
for title in train['titles']:
    for i in title:
        tok_freq[i] += 1
        
print(tok_freq)
# Out:
# Counter({'the': 92220, 'and': 54192, 'of': 50950, 'a': 31360, 'to': 27793, 'for': 21257, 'in': 21180, 'guide': 15942, 'edition': 12492, 'book': 8098, 'with': 7815, 'your': 7319, 'from': 6450, 'series': 6382, 'how': 5906, 'on': 5870, 'an': 5172, 'new': 4705, 'life': 4666, 'world': 4051, 'volume': 3987, 'history': 3980, 'you': 3798, '1': 3337, 'recipes': 3174, 'by': 3168, 'american': 3036, 'travel': 2935, 'complete': 2743, 'law': 2697, '2': 2684, 'story': 2644, 'art': 2605, 'handbook': 2548, 'health': 2543, 'my': 2495, 'books': 2403, 'science': 2284, 'at': 2165, 'calendar': 2147, 'best': 2074, 'novel': 2044, 'i': 2005, 'practice': 1987, 'map': 1935, 'cookbook': 1893, 'guides': 1885, 'that': 1851, 'vol': 1850, 'love': 1814, 'about': 1787, 'what': 1777, '2016': 1739, 'great': 1695, 'stories': 1676, 'war': 1659, 'business': 1626, 'more': 1621, 'it': 1598, 'is': 1595, 'introduction': 1576, 'second': 1573, 'modern': 1568, 'one': 1567, 'management': 1548, 'manual': 1543, 'america': 1521, 'other': 1519, '3': 1491, 'food': 1488, 'first': 1483, 'all': 1481, 'spanish': 1479, 'bible': 1461, 'through': 1461, 'study': 1441, 'home': 1431, 'easy': 1428, 'studies': 1427, 'library': 1405, 'design': 1398, 'day': 1387, 'kids': 1376, 'care': 1373, 'living': 1367, '2nd': 1348, 'family': 1342, 'practical': 1342, 'classics': 1329, 'time': 1284, 'city': 1273, 'techniques': 1263, 'national': 1246, 'who': 1242, 'essential': 1233, 'power': 1178, 'journey': 1177, 'international': 1164, 'way': 1163, 'school': 1155, 'know': 1154, 'english': 1147, 'de': 1144, '2015': 1139, 'making': 1136, 'people': 1116, 'ultimate': 1113, 'culture': 1110, 'can': 1108, 'diet': 1102, 'approach': 1100, 'children': 1098, 'little': 1087, 'our': 1082, 'women': 1078, 'theory': 1073, 'pocket': 1068, 'test': 1066, 'wall': 1065, 'secrets': 1058, 'true': 1041, '100': 1033, 'god': 1032, 'make': 1023, 'or': 1018, 'social': 1016, 'game': 1015, 'illustrated': 1014, 'exam': 1006, 'heart': 998, 'coloring': 995, 'review': 993, 'collection': 986, 'big': 986, 'atlas': 986, 'classic': 979, 'principles': 967, 'nursing': 967, 'medical': 964, 'no': 956, 'revised': 952, 'cooking': 949, 'set': 945, 'us': 944, 'do': 939, 'planet': 937, 'human': 923, 'understanding': 923, 'as': 921, 'most': 917, '4': 917, 'black': 916, 'worlds': 913, 'healthy': 910, 'natural': 906, 'clinical': 899, 'workbook': 891, 'ancient': 886, 'simple': 886, 'its': 882, 'learning': 882, 'sports': 880, 'into': 862, 'analysis': 859, 'out': 852, 'me': 850, 'real': 850, 'reference': 850, 'be': 849, 'their': 849, 'work': 848, '5': 842, 'development': 841, 'medicine': 836, 'man': 835, 'country': 825, 'research': 820, 'good': 818, 'years': 818, 'third': 816, 'up': 809, 'encyclopedia': 809, 'strategies': 808, 'north': 807, 'dummies': 807, 'get': 804, 'south': 797, 'lonely': 789, 'body': 788, 'healing': 783, '3rd': 781, 'why': 780, 'system': 780, 'two': 779, 'tales': 777, 'every': 776, 'everything': 769, 'writing': 769, 'secret': 767, 'official': 762, 'dover': 762, 'dictionary': 760, 'over': 758, 'building': 748, 'when': 747, 'using': 746, 'beyond': 731, 'systems': 731, 'adventure': 730, 'journal': 726, 'language': 726, 'legal': 724, 'are': 719, 'maps': 714, 'applications': 714, 'year': 712, 'student': 711, 'not': 708, 'ii': 707, 'professional': 706, 'age': 706, 'adventures': 705, 'skills': 701, 'we': 700, 'child': 699, 'oxford': 696, 'beginners': 690, 'questions': 687, 'weight': 686, 'french': 682, 'need': 678, 'young': 677, 'high': 672, 'change': 672, 'century': 669, 'training': 668, '2013': 663, 'advanced': 655, 'free': 654, 'his': 653, 'global': 652, '10': 651, 'level': 651, 'la': 649, 'field': 649, 'success': 647, 'days': 646, 'christmas': 645, 'house': 645, 'basic': 645, 'contemporary': 643, 'essentials': 640, '50': 639, 'street': 636, 'garden': 635, 'road': 633, 'mind': 633, 'chemistry': 631, 'made': 630, 'things': 628, 'survival': 628, 'state': 626, 'small': 625, 'inside': 624, 'delicious': 623, 'therapy': 622, 'physics': 621, 'techn ...

# %%
# group data by genre
# could probably be done MUCH nicer, but couldn't get for-loop to work...

grouped = train.groupby(train.genres)

Calendars = grouped.get_group("Calendars")
Comics = grouped.get_group("Comics & Graphic Novels")
Test = grouped.get_group("Test Preparation")
Mystery = grouped.get_group("Mystery, Thriller & Suspense")
SciFi = grouped.get_group("Science Fiction & Fantasy")
Romance = grouped.get_group("Romance")
Humor = grouped.get_group("Humor & Entertainment")
Literature = grouped.get_group("Literature & Fiction")
LGBTQ = grouped.get_group("Gay & Lesbian")
Engineering = grouped.get_group("Engineering & Transportation")
Food = grouped.get_group("Cookbooks, Food & Wine")
Crafts = grouped.get_group("Crafts, Hobbies & Home")
Arts = grouped.get_group("Arts & Photography")
Education = grouped.get_group("Education & Teaching")
Parenting = grouped.get_group("Parenting & Relationships")
SelfHelp = grouped.get_group("Self-Help")
Computers = grouped.get_group("Computers & Technology")
Medical = grouped.get_group("Medical Books")
Science = grouped.get_group("Science & Math")
Health = grouped.get_group("Health, Fitness & Dieting")
Business = grouped.get_group("Business & Money")
Law = grouped.get_group("Law")
Biographies = grouped.get_group("Biographies & Memoirs")
History = grouped.get_group("History")
Politics = grouped.get_group("Politics & Social Sciences")
Reference = grouped.get_group("Reference")
Bibles = grouped.get_group("Christian Books & Bibles")
Religion = grouped.get_group("Religion & Spirituality")
Sports = grouped.get_group("Sports & Outdoors")
Teen = grouped.get_group("Teen & Young Adult")
Childrens = grouped.get_group("Children's Books")
Travel = grouped.get_group("Travel")

GenreGroups = [Calendars['titles'], Comics['titles'], Test['titles'], Mystery['titles'], SciFi['titles'], 
               Romance['titles'], Humor['titles'], Literature['titles'], LGBTQ['titles'], Engineering['titles'], 
               Food['titles'], Crafts['titles'], Arts['titles'], Education['titles'], Parenting['titles'], 
               SelfHelp['titles'], Computers['titles'], Medical['titles'], Science['titles'], Health['titles'], 
               Business['titles'], Law['titles'], Biographies['titles'], History['titles'], Politics['titles'], 
               Reference['titles'], Bibles['titles'], Religion['titles'], Sports['titles'], Teen['titles'], 
               Childrens['titles'], Travel['titles']]

# %%
# token frequencies in each genre
genre_count = []
for g in GenreGroups:
    genre_title = Counter()
    for title in g:
        for i in title:
            genre_title[i] += 1
    genre_title = dict(genre_title)
    genre_count.append(genre_title)

# %%
# token frequencies in each genre
genre_count[0] # genres in same order as GenreGroups
# Out:
# {'moms': 10,
#  'family': 10,
#  'wall': 788,
#  'calendar': 1935,
#  '2016': 1116,
#  'doug': 1,
#  'the': 372,
#  'pug': 4,
#  'moleskine': 29,
#  'weekly': 59,
#  'notebook': 21,
#  '12m': 8,
#  'large': 24,
#  'black': 25,
#  'soft': 9,
#  'cover': 28,
#  '5': 14,
#  'x': 26,
#  '825': 13,
#  '365': 70,
#  'cats': 35,
#  'color': 11,
#  'pageaday': 60,
#  'sierra': 3,
#  'club': 5,
#  'engagement': 71,
#  'wilderness': 10,
#  'thomas': 11,
#  'kinkade': 8,
#  'disney': 25,
#  'dreams': 6,
#  'collection': 12,
#  'ansel': 3,
#  'adams': 3,
#  'dilbert': 5,
#  'daytoday': 84,
#  'mary': 8,
#  'engelbreit': 5,
#  'deluxe': 37,
#  'never': 3,
#  'give': 1,
#  'up': 8,
#  'cat': 23,
#  'gallery': 13,
#  'llewellyns': 4,
#  'witches': 2,
#  'datebook': 2,
#  'amy': 2,
#  'knapp': 2,
#  'big': 11,
#  'grid': 3,
#  'essential': 1,
#  'organization': 1,
#  'and': 137,
#  'communication': 1,
#  'tool': 1,
#  'for': 63,
#  'entire': 1,
#  'outlander': 2,
#  'audubon': 6,
#  'nature': 15,
#  'national': 19,
#  'park': 1,
#  'foundation': 1,
#  'extra': 4,
#  '75': 4,
#  '10': 4,
#  'pocket': 55,
#  '35': 7,
#  '55': 7,
#  'susan': 5,
#  'branch': 5,
#  'dog': 24,
#  'descendants': 1,
#  'walking': 1,
#  'dead': 2,
#  'today': 4,
#  'is': 11,
#  'going': 3,
#  'to': 47,
#  'be': 6,
#  'a': 98,
#  'great': 16,
#  'day': 34,
#  'french': 19,
#  'country': 23,
#  'diary': 15,
#  'pusheen': 2,
#  'posh': 8,
#  'coloring': 14,
#  'fun': 5,
#  'relaxation': 1,
#  '20152016': 25,
#  'monthlyweekly': 5,
#  'planning': 8,
#  'monthly': 77,
#  'planner': 86,
#  'smile': 1,
#  'its': 5,
#  'good': 4,
#  'you': 8,
#  'old': 7,
#  'farmers': 7,
#  'almanac': 11,
#  'gardening': 7,
#  'just': 37,
#  'being': 2,
#  'me': 3,
#  'almond': 1,
#  'blossoms': 1,
#  '16month': 41,
#  'birds': 8,
#  'new': 22,
#  'wordsayear': 2,
#  'chihuly': 2,
#  'song': 1,
#  'of': 216,
#  'ice': 1,
#  'fire': 5,
#  '18m': 11,
#  'legend': 1,
#  'zelda': 2,
#  'once': 1,
#  'upon': 1,
#  'time': 13,
#  'sloths': 1,
#  'blue': 4,
#  'grumpy': 1,
#  'yearinabox': 5,
#  'little': 10,
#  'world': 29,
#  'liz': 2,
#  'climo': 2,
#  'shoes': 3,
#  'orange': 6,
#  'circle': 6,
#  'studio': 9,
#  '17month': 4,
#  'do': 8,
#  'it': 7,
#  'all': 4,
#  'magnetic': 6,
#  'celestial': 4,
#  'wells': 1,
#  'street': 3,
#  'by': 122,
#  'lang': 7,
#  'planit': 1,
#  'plus': 1,
#  'august': 5,
#  '2015': 366,
#  'december': 31,
#  '12': 6,
#  '265': 1,
#  'inches': 1,
#  '7009167': 1,
#  'cynthia': 1,
#  'harts': 1,
#  'victoriana': 1,
#  'le': 2,
#  'petit': 2,
#  'prince': 2,
#  'limited': 9,
#  'edition': 119,
#  'hard': 17,
#  'john': 3,
#  'sloanes': 1,
#  'seasons': 3,
#  'away': 2,
#  'charles': 4,
#  'wysocki': 2,
#  'americana': 1,
#  'supernatural': 2,
#  'jeopardy': 3,
#  'nightmare': 2,
#  'before': 6,
#  'christmas': 12,
#  'bad': 6,
#  'organizer': 1,
#  'out': 6,
#  'on': 23,
#  'porch': 2,
#  '1000': 1,
#  'places': 3,
#  'see': 1,
#  'die': 1,
#  'secret': 4,
#  'garden': 43,
#  'book': 23,
#  'lovers': 10,
#  'downton': 5,
#  'abbey': 5,
#  'sugar': 3,
#  'skulls': 2,
#  'boxeddaily': 20,
#  'collectible': 3,
#  'teapot': 3,
#  'tea': 3,
#  'art': 60,
#  'cartoons': 1,
#  'from': 38,
#  'yorker': 2,
#  'underwater': 3,
#  'dogs': 7,
#  'star': 47,
#  'trek': 17,
#  'ships': 17,
#  'line': 6,
#  'bible': 8,
#  'versesayear': 1,
#  'dc': 1,
#  'bombshells': 1,
#  'jewish': 5,
#  'year': 55,
#  '5776': 1,
#  'peanuts': 9,
#  'islands': 1,
#  'wemoon': 1,
#  'gaia': 1,
#  'rhythms': 1,
#  'womyn': 1,
#  'quantum': 1,
#  'leap': 2,
#  'mystique': 1,
#  'xposed': 1,
#  'adult': 4,
#  'mystic': 1,
#  'playboy': 1,
#  'girls': 5,
#  'penthouse': 1,
#  'vixens': 1,
#  'nude': 5,
#  'naked': 1,
#  'hot': 3,
#  'sexy': 2,
#  'chases': 1,
#  'events': 3,
#  'ultimate': 7,
#  'goto': 1,
#  'guide': 10,
#  'special': 7,
#  'days': 31,
#  'weeks': 2,
#  'months': 2,
#  'hebrew': 1,
#  'illuminations': 1,
#  'original': 8,
#  'series': 13,
#  'taylor': 2,
#  'swift': 2,
#  'square': 180,
#  '12x12': 139,
#  'multilingual': 79,
#  'gooseberry': 8,
#  'patch': 8,
#  'calendars': 133,
#  'shaming': 1,
#  'wet': 1,
#  'unlikely': 1,
#  'friendships': 1,
#  'garfield': 4,
#  'oatmeal': 1,
#  'how': 2,
#  'tell': 1,
#  'if': 2,
#  'your': 13,
#  'plotting': 1,
#  'kill': 1,
#  'animal': 18,
#  'crossing': 1,
#  'songbirds': 1,
#  'other': 1,
#  'backyard': 1,
#  'pictureaday': 4,
#  'butterflies': 4,
#  '18month': 4,
#  'william': 5,
#  'wegman': 2,
#  'mans': 1,
#  'best': 6,
#  'friend': 2,
#  'gary': 4,
#  'pattersons': 3,
#  'catsbr': 1,
#  'puppiesayear': 1,
#  'dogma2016': 1,
#  'baby': 1,
#  'goats': 2,
#  'september': 28,
#  'through': 28,
#  'extraordinary': 2,
#  'chickens': 3,
#  'yoga': 12,
#  'lil': 1,
#  'bub': 1,
#  'mini': 121,
#  'hedgehogs': 1,
#  'what': 12,
#  'teach': 9,
#  'us': 15,
#  'space': 7,
#  'we': 2,
#  'love': 9,
#  'i': 9,
#  'could': 3,
#  'pee': 2,
#  'this': 6,
#  'horse': 26,
#  'puppies': 26,
#  'pembroke': 1,
#  'corgis': 1,
#  'trout': 1,
#  'north': 1,
#  'america': 5,
#  'desk': 36,
#  'pad': 6,
#  'mugs': 2,
#  'kittens': 13,
#  'dachshund': 1,
#  'in': 46,
#  'sweaters': 2,
#  'tales': 2,
#  'regret': 1,
#  'nothing': 1,
#  'memes': 1,
#  'audubons': 1,
#  'watercolors': 1,
#  'gypsy': 4,
#  'vanner': 4,
#  'goldendoodles': 2,
#  'texts': 1,
#  'owls': 4,
#  'wisdom': 15,
#  'golden': 7,
#  'retriever': 3,
#  'lurcher': 2,
#  'breed': 11,
#  'specific': 8,
#  'avonside': 45,
#  'corgi': 1,
#  'wild': 35,
#  'wildlife': 3,
#  'photography': 12,
#  'd': 1,
#  'mangelsen': 1,
#  'cartoona': 1,
#  'furbulous': 1,
#  'feline': 1,
#  'funnies': 1,
#  '13': 2,
#  'mysteries': 1,
#  'january': 1,
#  'joker': 1,
#  'february': 1,
#  'march': 1,
#  'mischief': 1,
#  'april': 1,
#  'adventure': 3,
#  'may': 1,
#  'magic': 6,
#  'june': 1,
#  'jam': 1,
#  'july': 3,
#  'jitters': 1,
#  'acrobat': 1,
#  'sneakers': 1,
#  'october': 1,
#  'ogre': 1,
#  'november': 1,
#  'night': 5,
#  'years': 5,
#  'eve': 1,
#  'thieves': 1,
#  'dachshunds': 2,
#  'debbie': 2,
#  'mumm': 2,
#  'checkbook2': 2,
#  '1986': 1,
#  'geographic': 8,
#  'waterfowl': 1,
#  '2014': 131,
#  'bunny': 2,
#  'suicides': 1,
#  'yorkies': 1,
#  'happy': 2,
#  'at': 14,
#  'box': 18,
#  'bulldogs': 2,
#  'maine': 5,
#  'coon': 3,
#  'naps': 5,
#  'tigers': 2,
#  'mysadcat': 1,
#  '7x7': 24,
#  'ivory': 3,
#  '11x14': 14,
#  'rachael': 2,
#  'hale': 2,
#  'why': 3,
#  'that': 11,
#  'dancing': 1,
#  'proverbial': 1,
#  'down': 4,
#  'east': 3,
#  'zen': 3,
#  'fat': 2,
#  'kitties': 2,
#  'tuxedo': 1,
#  'personal': 3,
#  '20162017': 8,
#  '2': 24,
#  '22016': 1,
#  'simons': 1,
#  'kitten': 2,
#  'magnum': 8,
#  'twoyear': 4,
#  'siamese': 2,
#  'cuddles': 1,
#  'hats': 1,
#  'paintings': 2,
#  'lesley': 2,
#  'anne': 5,
#  'whiskerslist': 1,
#  'angry': 1,
#  'ginger': 1,
#  'dogma': 2,
#  'boo': 3,
#  'bulldog': 2,
#  'chihuahua': 1,
#  'border': 2,
#  'terrier': 1,
#  'retrievers': 4,
#  'collies': 2,
#  'pomeranians': 1,
#  'shelties': 1,
#  'boxer': 1,
#  'westies': 1,
#  'german': 20,
#  'shepherds': 6,
#  'american': 44,
#  'kennel': 1,
#  'poodles': 2,
#  'miniature': 2,
#  'schnauzers': 1,
#  'basset': 2,
#  'hounds': 1,
#  'shepherd': 1,
#  'shorthaired': 1,
#  'pointers': 1,
#  'boys': 3,
#  'shih': 2,
#  'tzu': 2,
#  'chocolate': 2,
#  'labs': 2,
#  'only': 5,
#  'rottweilers': 1,
#  'yellow': 3,
#  'australian': 1,
#  'scottish': 2,
#  'terriers': 4,
#  'greyhounds': 1,
#  'beagle': 2,
#  'rules': 1,
#  'maltese': 1,
#  'bernese': 1,
#  'mountain': 5,
#  'siberian': 3,
#  'husky': 3,
#  'lab': 1,
#  'eskimo': 1,
#  'eskimos': 1,
#  'pooped': 2,
#  'cairn': 1,
#  'hound': 2,
#  'labradoodle': 2,
#  'mastiff': 2,
#  'collie': 2,
#  'wheaten': 1,
#  'coated': 1,
#  'shiba': 4,
#  'inu': 4,
#  'toy': 1,
#  'chew': 2,
#  'shetland': 3,
#  'sheepdog': 2,
#  'happiness': 4,
#  'horses': 47,
#  'quarter': 3,
#  'portrait': 2,
#  'painted': 1,
#  'ponies': 4,
#  'arabians': 2,
#  'feathers': 1,
#  'western': 3,
#  'horseman': 1,
#  'cowboy': 1,
#  'paint': 2,
#  'fantasy': 7,
#  'clydesdales': 1,
#  '160640': 1,
#  'english': 16,
#  'spanish': 19,
#  'italian': 14,
#  'arabian': 2,
#  'wyman': 15,
#  'racing': 2,
#  'dressage': 1,
#  'hunter': 2,
#  'jumper': 1,
#  '366': 3,
#  'cowboys': 1,
#  'mustangs': 2,
#  'west': 1,
#  'spirit': 7,
#  'harrison': 1,
#  'stephen': 1,
#  'king': 2,
#  '2006': 8,
#  'includes': 5,
#  'short': 1,
#  'story': 2,
#  'my': 8,
#  'pretty': 2,
#  'pony': 1,
#  'freedom': 2,
#  'federation': 1,
#  '161537': 1,
#  'sense': 1,
#  'official': 109,
#  'fools': 1,
#  'slim': 9,
#  'dreaming': 1,
#  'poster': 27,
#  'helma': 13,
#  'mist': 2,
#  'bonus': 5,
#  'download': 1,
#  'graphique': 2,
#  'colts': 3,
#  'fillies': 1,
#  'photographs': 10,
#  'tony': 1,
#  'stromberg': 1,
#  'doubleview': 2,
#  'easel': 8,
#  'haunted': 1,
#  'realm': 2,
#  'castles': 4,
#  'skyscrapers': 1,
#  'worlds': 6,
#  'most': 6,
#  'buildings': 2,
#  'barns': 1,
#  'things': 9,
#  'come': 3,
#  'apart': 2,
#  'lighthouses': 66,
#  'farm': 1,
#  'hundertwasser': 1,
#  'architecture': 9,
#  'gaudi': 3,
#  'taschen': 7,
#  'spiral': 8,
#  'diaries': 4,
#  'master': 3,
#  'drawings': 3,
#  'frank': 14,
#  'lloyd': 7,
#  'wright': 7,
#  'bridges': 3,
#  '2012': 68,
#  'lighthouse': 16,
#  'treehouses': 4,
#  'outhouses': 4,
#  '2004': 6,
#  'road': 1,
#  'home': 4,
#  'designs': 4,
#  '12month': 11,
#  'featuring': 18,
#  'wonderful': 5,
#  'write': 1,
#  'key': 1,
#  'landmarks': 2,
#  'cal': 4,
#  '96': 1,
#  'parks': 4,
#  'atlantic': 3,
#  'coast': 10,
#  'england': 2,
#  'timeless': 3,
#  'visions': 1,
#  'chicago': 2,
#  'sports': 24,
#  'venues': 1,
#  'wrights': 1,
#  'dream': 11,
#  'houses': 2,
#  'christian': 1,
#  'herb': 2,
#  'ritts': 1,
#  '1996': 1,
#  'doorway': 1,
#  'every': 6,
#  'with': 27,
#  'over': 1,
#  'photos': 4,
#  '2013': 90,
#  'archipendium': 1,
#  'full': 3,
#  'norman': 2,
#  'rockwell': 2,
#  'saturday': 2,
#  'evening': 2,
#  'post': 2,
#  'lakes': 5,
#  'paris': 6,
#  'glitz': 1,
#  'georgia': 4,
#  'okeeffe': 1,
#  'tiffany': 2,
#  'pacific': 5,
#  '2011': 36,
#  'tractors': 3,
#  'york': 10,
#  'irish': 3,
#  'pubs': 1,
#  '2009': 19,
#  'colt': 1,
#  'leather': 1,
#  'charley': 2,
#  'harper': 2,
#  'month': 80,
#  'blotter': 1,
#  'painter': 2,
#  'light': 2,
#  'scripture': 3,
#  'collectors': 4,
#  'majesty': 2,
#  'masterpieces': 2,
#  'attitude': 1,
#  'everything': 1,
#  'polka': 1,
#  'dots': 1,
#  'advent': 20,
#  'bless': 1,
#  'destress': 1,
#  'season': 1,
#  'edward': 8,
#  'gorey': 1,
#  'painters': 6,
#  'floral': 5,
#  'masha': 1,
#  'dyans': 1,
#  'an': 5,
#  '300': 2,
#  'beautiful': 3,
#  'pages': 2,
#  'stressfree': 1,
#  'relaxing': 1,
#  'creative': 2,
#  'tokidoki': 1,
#  'private': 1,
#  'presents': 5,
#  'totally': 2,
#  'chick': 1,
#  'girl': 5,
#  'women': 17,
#  'myth': 1,
#  'environmental': 1,
#  'contemporary': 2,
#  'natural': 1,
#  'bev': 1,
#  'doolittlebrbr': 1,
#  'impressionism': 3,
#  'postimpressionism': 2,
#  'lotta': 1,
#  'jansdotter': 1,
#  'cobblestone': 1,
#  'way': 8,
#  'lets': 1,
#  'pretend': 1,
#  'happened': 1,
#  'david': 1,
#  'olenick': 1,
#  'classic': 31,
#  'posters': 2,
#  'covers': 1,
#  'land': 1,
#  'creations': 1,
#  'quilt': 20,
#  'engagment': 2,
#  'broadway': 1,
#  'gardens': 26,
#  'grace': 4,
#  'soul': 3,
#  'mc': 1,
#  'escher': 1,
#  'place': 7,
#  'studs': 1,
#  'n': 1,
#  'spurs': 1,
#  'kim': 1,
#  'parker': 1,
#  'perpetual': 34,
#  'redstone': 2,
#  'therapeutic': 1,
#  'books': 3,
#  'holly': 1,
#  'randalls': 1,
#  'hotties': 1,
#  'lingerie': 2,
#  'kitchen': 4,
#  'patterns': 4,
#  '17': 8,
#  'shepard': 1,
#  'fairey': 1,
#  'graphic': 2,
#  'activist': 1,
#  'simplicity': 2,
#  'chalk': 3,
#  'daily': 43,
#  'desktop': 9,
#  'inuit': 2,
#  'artcape': 1,
#  'dorset': 2,
#  'small': 3,
#  'untroubled': 1,
#  'gustave': 1,
#  'baumann': 1,
#  'hyperbole': 4,
#  'half': 4,
#  'illusion': 1,
#  'serenity': 2,
#  'chippendales': 1,
#  'calen': 1,
#  'bike': 2,
#  'bicycle': 1,
#  'movie': 5,
#  'film': 1,
#  'registry': 1,
#  'library': 4,
#  'congress': 1,
#  'fenderâ®': 1,
#  'custom': 2,
#  'shop': 3,
#  'guitars': 6,
#  'keith': 2,
#  'haring': 1,
#  'engelbreits': 1,
#  'can': 2,
#  'anything': 1,
#  '201516': 1,
#  'coffee': 5,
#  'supercars': 2,
#  'cars': 30,
#  'autocourse': 2,
#  'grand': 3,
#  'prix': 2,
#  'contains': 2,
#  'dates': 2,
#  'muscle': 8,
#  'porsche': 2,
#  'car': 15,
#  'automobile': 13,
#  'jeep': 1,
#  'offroad': 1,
#  'trucks': 6,
#  'action': 4,
#  '16': 62,
#  'corvette': 9,
#  'stsilver': 2,
#  'foil': 8,
#  'classics': 5,
#  'ferrari': 4,
#  'sting': 2,
#  'ray': 2,
#  'caraday': 2,
#  'volkswagen': 1,
#  'bus': 1,
#  'monster': 4,
#  'pixar': 3,
#  'camaro': 5,
#  'ford': 5,
#  'mustang': 3,
#  '17x12': 2,
#  'print': 5,
#  '1970': 1,
#  'boss': 2,
#  '302': 1,
#  '1966': 1,
#  'l72': 1,
#  'convertible': 1,
#  'aston': 1,
#  'martin': 1,
#  'james': 1,
#  'bond': 1,
#  'gt': 1,
#  'automobiles': 2,
#  'plato': 1,
#  'vintage': 20,
#  'citroen': 1,
#  'british': 8,
#  'f1': 2,
#  '30x30cm': 1,
#  'vw': 3,
#  'campers': 2,
#  'jaguar': 1,
#  'farmall': 1,
#  'trucker': 1,
#  'beetle': 1,
#  'stred': 1,
#  'harleydavidson': 1,
#  'dayatatime': 2,
#  'fiat': 1,
#  '500': 1,
#  'pickups': 1,
#  'exif': 1,
#  'motorcycle': 1,
#  'gto': 1,
#  'cruisin': 1,
#  'chrome': 1,
#  'motorsport': 1,
#  'retro': 3,
#  'including': 2,
#  'superbikes': 3,
#  'danica': 1,
#  'patrick': 1,
#  'seven': 5,
#  'seas': 5,
#  'sailors': 5,
#  'motor': 1,
#  'boats': 17,
#  'sailing': 23,
#  'harbors': 1,
#  'wooden': 11,
#  'tall': 10,
#  'sail': 5,
#  'mark': 3,
#  'sailor': 2,
#  'moon': 3,
#  'wandkalender': 2,
#  '160326': 1,
#  'photoart': 1,
#  'kalender': 1,
#  'thirtyfirst': 1,
#  'executive': 3,
#  'j': 3,
#  'levine': 2,
#  '5774': 1,
#  '2013december': 1,
#  'shipping': 2,
#  'now': 3,
#  'white': 1,
#  'basketball': 4,
#  '2007': 10,
#  'chriscraft': 1,
#  'power': 3,
#  'wind': 4,
#  'trip': 1,
#  'lifetime': 1,
#  'calvendo': 1,
#  'japanese': 4,
#  'anime': 1,
#  'guardian': 1,
#  'bishojo': 1,
#  'senshi': 1,
#  'crystal': 2,
#  'mariners': 2,
#  'cruising': 3,
#  'dr': 4,
#  'crash': 2,
#  'oceanliners': 1,
#  'media': 6,
#  'illustration': 7,
#  'naruto': 1,
#  'shippuden': 1,
#  '2010': 22,
#  'shonen': 1,
#  'jump': 1,
#  'motorboats': 2,
#  '5772': 1,
#  '2011december': 1,
#  'regatta': 1,
#  '3044612': 1,
#  'honor': 2,
#  'harrington': 2,
#  'fleet': 2,
#  'titanic': 1,
#  'super': 2,
#  'vertical': 1,
#  '2008': 15,
#  'nautical': 2,
#  'ocean': 1,
#  'liners': 1,
#  'shipshape': 1,
#  'elements': 1,
#  'dancers': 3,
#  '51031': 1,
#  '2002': 7,
#  '2003': 3,
#  'boatsâ®': 1,
#  'harry': 13,
#  'potter': 13,
#  'tolkien': 10,
#  'eric': 2,
#  'carletm': 1,
#  'carles': 1,
#  'snow': 1,
#  'popup': 3,
#  'lord': 8,
#  'rings': 8,
#  'trilogy': 2,
#  'wintervillage': 1,
#  'winnie': 5,
#  'pooh': 5,
#  'winters': 1,
#  'journey': 3,
#  'manger': 1,
#  'adventures': 1,
#  'odyssey': 1,
#  'childrens': 1,
#  'cl53341': 1,
#  'elsa': 2,
#  'beskow': 2,
#  'puggle': 1,
#  'nutcracker': 1,
#  'set': 3,
#  'woods': 1,
#  'bethlehem': 1,
#  'tintin': 1,
#  'caillou': 1,
#  'waits': 1,
#  'santa': 1,
#  'woodland': 3,
#  'owl': 1,
#  'babies': 1,
#  'stickers': 2,
#  'sketch': 1,
#  'abcs': 1,
#  'kids': 9,
#  'hobbit': 3,
#  'twas': 1,
#  'silent': 1,
#  'usa': 6,
#  'travel': 1,
#  'journal': 7,
#  'hiking': 1,
#  'angels': 2,
#  'carol': 1,
#  'workman': 1,
#  'undated': 2,
#  'diariesadvent': 1,
#  'babys': 3,
#  'first': 4,
#  'nurse': 1,
#  'wtwosided': 1,
#  'incl': 1,
#  '201112': 1,
#  'class': 1,
#  'friends': 4,
#  'wrestling': 2,
#  'wwe': 4,
#  'a3': 10,
#  'kindergarten': 1,
#  'theme': 1,
#  'sticker': 1,
#  'activity': 5,
#  'dover': 1,
#  'boxed': 12,
#  'schipperke': 1,
#  'seuss': 1,
#  '2001': 4,
#  'deathly': 1,
#  'hallows': 1,
#  'griffin': 2,
#  'dragon': 7,
#  'week': 4,
#  'like': 3,
#  'stories': 3,
#  '1978': 1,
#  'r': 4,
#  'illustrations': 2,
#  'brothers': 2,
#  'hildebrandt': 1,
#  'entlebucher': 1,
#  'artwork': 3,
#  'postcard': 1,
#  'wishes': 1,
#  'paper': 4,
#  'pals': 1,
#  'doll': 1,
#  'jessie': 1,
#  'willcox': 1,
#  'smith': 2,
#  'cl53182': 1,
#  'grandpre': 1,
#  'goblet': 1,
#  'winniethepoohs': 1,
#  '2005': 5,
#  ...}

# %%
# number of words in a class
len(genre_count[0]) # first genre
# Out:
# 2384

# %%
# number of total vocabulary (training set)
V = len(Counter(tok_freq))
print(V)
# Out:
# 74773

# %%
# number of titles (in training set)
N_titles = len(train)
print(N_titles)
# Out:
# 165688

# %%
# number of titles in each genre
N_genre = train['genres'].value_counts()
print(N_genre[:5])
# Out:
# Travel                       14650
# Children's Books             10886
# Medical Books                 9601
# Health, Fitness & Dieting     9483
# Business & Money              7990
# Name: genres, dtype: int64

# %% [markdown]
# ### Priors

# %%
# priors of each genre (probability of title being in specific genre)
prob_title = []
for g in range(len(N_genre)):
    prob = N_genre[g] / N_titles
    prob_title.append(prob)

zipped_values = zip(df1.genre.unique(), prob_title)
prior = list(zipped_values)

print(prior[:5]) # test
# Out:
# [('Calendars', 0.08841919752788373), ('Comics & Graphic Novels', 0.06570180097532712), ('Test Preparation', 0.05794626044131138), ('Mystery, Thriller & Suspense', 0.057234078509004874), ('Science Fiction & Fantasy', 0.04822316643329631)]

# %% [markdown]
# ### Likelihoods

# %%
# likelihoods of each word (probability of word being in specific genre)

# create empty dataframe
likelihood = pd.DataFrame(columns=df1.genre.unique(), index=dict.keys(tok_freq))

len_gc = -1
for i in genre_count: # loop through genres
    len_gc += 1 # create genre index
    for word in i: 
        p = (genre_count[len_gc][word] + 1) / (len(genre_count[len_gc]) + V) # probability
        likelihood.loc[word, likelihood.columns[len_gc]] = p # replace NaN in dataframe with p

# %%
# now fill likelihoods of words that haven't appeared in genre

len_gc = -1
for c, v in likelihood.iteritems(): # loop through genres in dataframe
  len_gc += 1 # create genre index
  p = 1 / (len(genre_count[len_gc]) + V) # probability of word not appearing in that genre
  likelihood[c].fillna(p, inplace=True) # replace remaining NaNs in dataframe with p

# %%
likelihood
# Out:
#                Calendars  Comics & Graphic Novels  ...  Children's Books    Travel
# moms            0.000143                 0.000025  ...          0.000047  0.000045
# family          0.000143                 0.000153  ...          0.000654  0.001112
# wall            0.010226                 0.000013  ...          0.000222  0.000352
# calendar        0.025092                 0.000013  ...          0.000047  0.000341
# 2016            0.014477                 0.000013  ...          0.000128  0.001260
# ...                  ...                      ...  ...               ...       ...
# flashmaps       0.000013                 0.000013  ...          0.000012  0.000023
# ballrooms       0.000013                 0.000013  ...          0.000012  0.000023
# riverboat       0.000013                 0.000013  ...          0.000012  0.000023
# historymapped   0.000013                 0.000013  ...          0.000012  0.000023
# 1790            0.000013                 0.000013  ...          0.000012  0.000023
#
# [74773 rows x 32 columns]

# %%
# predictions on word by word basis using words in titles of test data

predictors = pd.DataFrame(columns=df1.genre.unique(), index=dict.keys(tok_freq)) # create empty dataframe
len_gc = -1
for i in prior:
  len_gc += 1 # create genre index
  # square all likelihoods then multiply them each with prior of that genre
  predictors = likelihood.loc[:, df1.genre.unique().tolist()] ** 2 # square likelihoods
  predictors = predictors.loc[:, df1.genre.unique().tolist()] * np.array(prior[len_gc][1]) # multiply by priors

# %%
predictors
# Out:
#                   Calendars  ...        Travel
# moms           1.283144e-10  ...  1.301453e-11
# family         1.283144e-10  ...  7.811972e-09
# wall           6.601520e-07  ...  7.816853e-10
# calendar       3.974666e-06  ...  7.320674e-10
# 2016           1.323111e-06  ...  1.002200e-08
# ...                     ...  ...           ...
# flashmaps      1.060449e-12  ...  3.253633e-12
# ballrooms      1.060449e-12  ...  3.253633e-12
# riverboat      1.060449e-12  ...  3.253633e-12
# historymapped  1.060449e-12  ...  3.253633e-12
# 1790           1.060449e-12  ...  3.253633e-12
#
# [74773 rows x 32 columns]

# %%
predictors.loc[["moms"]]
# Out:
#          Calendars  Comics & Graphic Novels  ...  Children's Books        Travel
# moms  1.283144e-10             4.099988e-12  ...      1.375690e-11  1.301453e-11
#
# [1 rows x 32 columns]

# %%
# save predictors so these don't have to be created again when testing model
predictors.to_csv('/drive/My Drive/predictors_NB.csv')

# %%
# output genre that has highest prediction value for input word
maxValueIndexObj = predictors.idxmax(axis=1)
print(list(maxValueIndexObj[["high"]]))
print(list(maxValueIndexObj[["higher"]]))
print(list(maxValueIndexObj[["highest"]]))
# Out:
# ['Health, Fitness & Dieting']
# ['Education & Teaching']
# ['Christian Books & Bibles']

# %% [markdown]
# ### Test model

# %%
# function that will return list of predicted genres based on title input
# function is very slow -> OPTIMIZE (otherwise takes 11.5hrs for test dataset...)
def pred_genre(title):
  prediction = []
  for w in title:
    ## CONDITION: if word exists in total vocabulary
    if w in predictors.index:
      maxValueIndexObj = predictors.idxmax(axis=1)
      prediction += list(maxValueIndexObj[[w]])
    ## CONDITION: if word does not exist in total vocabulary
    if w not in predictors.index:
      pass

  # probability of predicted genre being chosen
  d = dict(Counter(prediction))
  d1 = {k: v / total for total in (sum(d.values()),) for k, v in d.items()}

  # output most likely predicted genre
  if prediction == []:
    return 'There is no prediction for this title.'
  else:
    return max(d1, key=d1.get) 
  
  # what if there is no maximum? (all equally predicted)
  # gives first predicted genre as output...

# %%
# predicted genre for first test title
import time
time_start = time.clock()

pred_genre(test['titles'][0])

time_elapsed = (time.clock() - time_start)
print(time_elapsed)
# Out:
# 1.0751810000000006

# %%
pred_genre(test['titles'][678])
# Out:
# 'Comics & Graphic Novels'

# %%
# "real" genre of first test title
test['genres'][0]
# Out:
# 'Calendars'

# %%
# titles that would give no prediction:
# these titles are one word long and not included in training set
for t in test['titles']:
  if len(t) == 1:
    for w in t:
      if w not in list(tok_freq.keys()):
        print(t)
  else:
    pass
# Out:
# ['dã¼sseldorf']
# ['unflattening']
# ['poseidont']
# ['verboten']
# ['peplum']
# ['megahex']
# ['escapo']
# ['mw']
# ['priapus']
# ['stroppy']
# ['cryptonomicon']
# ['cyberstorm']
# ['robogenesis']
# ['nightfolk']
# ['moonheart']
# ['abilites']
# ['binti']
# ['saucer']
# ['eifelheim']
# ['sharkman']
# ['pornucopia']
# ['cryptonomicon']
# ['cuckd']
# ['edenbrooke']
# ['lespada']
# ['genafinn']
# ['equivocation']
# ['hippochondriac']
# ['ctrlshift']
# ['shibumi']
# ['nyctophobia']
# ['cryptos']
# ['fingersmith']
# ['penpal']
# ['fantasmagoria']
# ['neverhome']
# ['habibi']
# ['pnin']
# ['kokoro']
# ['divisadero']
# ['downtime']
# ['laodicea']
# ['godlike']
# ['tacopedia']
# ['rockpool']
# ['koto']
# ['morito']
# ['balloonology']
# ['remodelista']
# ['skyshades']
# ['unbranded']
# ['plasticland']
# ['orthopantomography']
# ['amlodipine']
# ['schistosomiasis']
# ['nextinction']
# ['palomino']
# ['weology']
# ['coopetition']
# ['serpico']
# ['recapitulations']
# ['sleepers']
# ['oct64']
# ['mariology']
# ['dispensationalism']
# ['skatekey']
# ['boneseeker']
# ['mimus']
# ['guyliner']
# ['bunheads']
# ['edgewater']
# ['evertaster']
# ['wildthorn']
# ['perdita']
# ['truthwitch']
# ['orangutangled']
# ['petunia']
# ['tiddler']
# ['fartiste']
# ['nightbird']
# ['bonylegs']
# ['exploralab']
# ['serendib']
# ['kanaval']
# ['uruguayparaguay']

# %%
######## this function takes 9.25 hours!!
predicted_genre = []
for t in test['titles']:
  predicted_genre.append(pred_genre(t))


# change list to dataframe to enable saving as csv file
df2 = pd.DataFrame(predicted_genre)
df2.columns = ['Predicted Genre']
df2['True Genre'] = test['genres']

# create and save csv file in Google Drive
df2.to_csv('/drive/My Drive/predicted_genre_NB.csv')

# %%
# read csv file as pandas Dataframe
predicted_genre = pd.read_csv('/drive/My Drive/predicted_genre_NB.csv',encoding='latin1')

# %%
# dataframe with predicted and true genres
predicted_genre
# Out:
#        Unnamed: 0          Predicted Genre True Genre
# 0               0                Calendars  Calendars
# 1               1                Calendars  Calendars
# 2               2                Calendars  Calendars
# 3               3  Religion & Spirituality  Calendars
# 4               4                Calendars  Calendars
# ...           ...                      ...        ...
# 41879       41879                   Travel     Travel
# 41880       41880                   Travel     Travel
# 41881       41881                   Travel     Travel
# 41882       41882                   Travel     Travel
# 41883       41883                   Travel     Travel
#
# [41884 rows x 3 columns]

# %% [markdown]
# ### Accuracy of model

# %%
# read csv file as pandas Dataframe
predicted_genre = pd.read_csv('/drive/My Drive/predicted_genre_NB.csv',encoding='latin1')

# %%
# compute overall accuracy, precision, recall, f1 scores
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

print('Accuracy: ', accuracy_score(predicted_genre['True Genre'], predicted_genre['Predicted Genre']))
print('Precision: ', precision_score(predicted_genre['True Genre'], predicted_genre['Predicted Genre'], average='weighted'))
print('Recall: ', recall_score(predicted_genre['True Genre'], predicted_genre['Predicted Genre'], average='weighted', zero_division=1))
print('F1:', f1_score(predicted_genre['True Genre'], predicted_genre['Predicted Genre'], average='weighted'))
# Out:
# Accuracy:  0.43608537866488395
# Precision:  0.5212100104488911
# Recall:  0.43608537866488395
# F1: 0.4201469237616296

# %%
# compute accuracy, precision, recall, f1 scores by genre

from sklearn.metrics import precision_recall_fscore_support as score

# precision, recall, fscore, support separated by genre
precision, recall, fscore, support = score(predicted_genre['True Genre'], predicted_genre['Predicted Genre'])

df_acc = pd.DataFrame()
df_acc['precision']=pd.Series(precision)
df_acc['recall']=pd.Series(recall)
df_acc['fscore']=pd.Series(fscore)
df_acc['support']=pd.Series(support)

print(df_acc)
# order corresponds to genre IDs, with some exceptions
# order: 0-9, 31, 10, 30, 11-28, no prediction, 29
# Out:
#     precision    recall    fscore  support
# 0    0.572277  0.213284  0.310753     1355
# 1    0.247253  0.054348  0.089109      828
# 2    0.560174  0.457215  0.503485     1975
# 3    0.822835  0.762774  0.791667      548
# 4    0.428305  0.507540  0.464568     2719
# 5    0.545894  0.372732  0.442992     1819
# 6    0.628125  0.323151  0.426752      622
# 7    0.689172  0.683081  0.686113     1584
# 8    0.700734  0.686774  0.693684     1807
# 9    0.665145  0.437000  0.527459     2000
# 10   0.578125  0.120915  0.200000      306
# 11   0.620690  0.203390  0.306383      531
# 12   0.389831  0.078498  0.130682      293
# 13   0.284167  0.709530  0.405807     2403
# 14   0.314345  0.333333  0.323561     1374
# 15   0.586895  0.155004  0.245238     1329
# 16   0.710946  0.447492  0.549261     1495
# 17   0.475120  0.199730  0.281235     1482
# 18   0.629484  0.642656  0.636002     2485
# 19   0.487179  0.128378  0.203209      444
# 20   0.410000  0.077652  0.130573      528
# 21   0.419048  0.065967  0.113990      667
# 22   0.586047  0.192366  0.289655      655
# 23   0.608295  0.258824  0.363136     1530
# 24   0.535620  0.232532  0.324281      873
# 25   0.617719  0.402029  0.487063     1873
# 26   0.632479  0.289062  0.396783      768
# 27   0.328358  0.039427  0.070400      558
# 28   0.560510  0.220183  0.316168     1199
# 29   0.511364  0.115533  0.188482     1558
# 30   0.778203  0.692177  0.732673      588
# 31   0.000000  0.000000  0.000000        0
# 32   0.261142  0.905640  0.405389     3688
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# save model evaluation as csv file in Google Drive
df_acc.to_csv('/drive/My Drive/NB_model_eval.csv')
